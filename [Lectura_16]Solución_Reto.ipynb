# %% [markdown]
# <a href="https://colab.research.google.com/github/DLesmes/ML_Text_Classifier_Algorithms/blob/main/%5BLectura_16%5DSoluci%C3%B3n_Reto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Construcción de un modelo markoviano de máxima entropía

# %%
# !pip install conllu
# !pip install stanza
# !git clone https://github.com/UniversalDependencies/UD_Spanish-AnCora.git
# Out:
# Collecting conllu
#   Downloading https://files.pythonhosted.org/packages/ae/be/be6959c3ff2dbfdd87de4be0ccdff577835b5d08b1d25bf7fd4aaf0d7add/conllu-4.4-py2.py3-none-any.whl
# Installing collected packages: conllu
# Successfully installed conllu-4.4
# Collecting stanza
#   Downloading https://files.pythonhosted.org/packages/50/ae/a70a58ce6b4e2daad538688806ee0f238dbe601954582a74ea57cde6c532/stanza-1.2-py3-none-any.whl (282kB)
#      |████████████████████████████████| 286kB 13.0MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from stanza) (4.41.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from stanza) (2.23.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.7/dist-packages (from stanza) (3.12.4)
# Requirement already satisfied: torch>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from stanza) (1.8.1+cu101)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from stanza) (1.19.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->stanza) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->stanza) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->stanza) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->stanza) (1.24.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from protobuf->stanza) (54.2.0)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from protobuf->stanza) (1.15.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.3.0->stanza) (3.7.4.3)
# Installing collected packages: stanza
# Successfully installed stanza-1.2
# Cloning into 'UD_Spanish-AnCora'...
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 578 (delta 4), reused 6 (delta 2), pack-reused 569
# Receiving objects: 100% (578/578), 145.83 MiB | 25.13 MiB/s, done.
# Resolving deltas: 100% (399/399), done.

# %% [markdown]
# ### Entrenamiento del modelo - cálculo de conteos
#
# Parta este modelo consideramos el cálculo de las probabilidades:
#
# $$P(t_i | w_i, t_{i-1}) =\frac{C(w_i, t_i, t_{i-1})}{C(w_i, t_{i-1})} $$
#
# * `uniqueFeatureDict` $C(tag|word,prevtag) = C(w_i, t_i, t_{i-1})$
# * `contextDict` $C(word,prevtag) = C(w_i, t_{i-1})$
#
# En este caso cuando consideremos el primer elemento de una frase $w_0$, no existirá un elemento anterior $w_{-1}$ y por lo tanto, tampoco una etiqueta previa $t_{-1}$, podemos modelar este problema asumiendo que existe una etiqueta "None", para estos casos:
#
# $$P(t_0|w_0,t_{-1}) = P(t_0|w_0,\text{"None"})$$

# %%
from conllu import parse_incr

uniqueFeatureDict = {}
contextDict = {}

data_file = open("UD_Spanish-AnCora/es_ancora-ud-train.conllu", "r", encoding="utf-8")

# Calculando conteos (pre-probabilidades)
for tokenlist in parse_incr(data_file):
  prevtag = "None"
  for token in tokenlist:
    tag = token['upos']
    word = token['form'].lower()
    largeKey = tag+'|'+word+','+prevtag
    if largeKey in uniqueFeatureDict.keys():
      uniqueFeatureDict[largeKey]+=1
    else:
      uniqueFeatureDict[largeKey]=1
    key = word+','+prevtag
    if key in contextDict.keys():
      contextDict[key]+=1
    else:
      contextDict[key]=1
    prevtag=tag

# %%
uniqueFeatureDict
# Out:
# {'DET|el,None': 2163,
#  'NOUN|presidente,DET': 325,
#  'ADP|del,NOUN': 3987,
#  'NOUN|órgano,ADP': 3,
#  'ADJ|regulador,NOUN': 4,
#  'ADP|de,ADJ': 2329,
#  'DET|las,ADP': 2367,
#  'PROPN|telecomunicaciones,DET': 5,
#  'PRON|se,PROPN': 415,
#  'VERB|mostró,PRON': 47,
#  'ADJ|partidario,VERB': 8,
#  'VERB|completar,ADP': 7,
#  'DET|esta,VERB': 104,
#  'NOUN|liberalización,DET': 9,
#  'ADP|de,NOUN': 16787,
#  'NOUN|telecomunicaciones,DET': 7,
#  'ADP|con,NOUN': 990,
#  'DET|otras,ADP': 72,
#  'NOUN|medidas,DET': 45,
#  'PRON|que,NOUN': 2305,
#  'VERB|incentiven,PRON': 1,
#  'DET|la,VERB': 2291,
#  'NOUN|competencia,DET': 37,
#  'SCONJ|como,NOUN': 318,
#  'NOUN|puede,SCONJ': 1,
#  'NOUN|ser,NOUN': 2,
#  'VERB|abrir,NOUN': 1,
#  'DET|el,VERB': 2564,
#  'NOUN|acceso,DET': 21,
#  'ADP|a,NOUN': 1894,
#  'DET|la,ADP': 9149,
#  'NOUN|información,DET': 38,
#  'DET|los,ADP': 4008,
#  'NOUN|clientes,DET': 15,
#  'PROPN|telefónica,ADP': 53,
#  'ADP|a,PROPN': 256,
#  'DET|otros,ADP': 98,
#  'NOUN|operadores,DET': 7,
#  'PUNCT|.,NOUN': 5650,
#  'ADP|sobre,None': 26,
#  'NOUN|oferta,DET': 44,
#  'NOUN|interconexión,ADP': 5,
#  'ADP|de,PROPN': 2321,
#  'VERB|acaba,PRON': 11,
#  'ADP|de,VERB': 1191,
#  'VERB|aprobar,ADP': 5,
#  'PROPN|cmt,DET': 1,
#  'PUNCT|,,PROPN': 7038,
#  'PROPN|vázquez,PUNCT': 1,
#  'PROPN|quintana,PROPN': 5,
#  'VERB|dijo,PROPN': 53,
#  'SCONJ|que,VERB': 2753,
#  'ADP|para,SCONJ': 41,
#  '_|desarrollarla,ADP': 1,
#  'VERB|desarrollar,_': 3,
#  'PRON|la,VERB': 91,
#  'AUX|han,PRON': 276,
#  'VERB|escuchado,AUX': 6,
#  'ADP|a,VERB': 3118,
#  'ADJ|actuales,NOUN': 15,
#  'CCONJ|y,ADJ': 1608,
#  'ADP|a,CCONJ': 251,
#  'PRON|otros,ADP': 39,
#  'PRON|que,PRON': 756,
#  'ADV|pronto,PRON': 1,
#  'VERB|darán,ADV': 2,
#  'NOUN|servicios,VERB': 10,
#  'CCONJ|y,NOUN': 3433,
#  'SCONJ|que,CCONJ': 396,
#  'ADP|al,SCONJ': 30,
#  'VERB|tener,ADP': 49,
#  'VERB|aunar,SCONJ': 1,
#  'DET|tantos,VERB': 4,
#  'NOUN|intereses,DET': 32,
#  'AUX|es,NOUN': 505,
#  'ADJ|imposible,AUX': 14,
#  'VERB|dejar,ADJ': 1,
#  'ADJ|satisfechos,VERB': 2,
#  'ADP|a,ADJ': 862,
#  'PRON|todos,ADP': 39,
#  'PUNCT|.,PRON': 276,
#  'VERB|afirmó,None': 6,
#  'VERB|sigue,SCONJ': 4,
#  'NOUN|criterio,DET': 6,
#  'ADJ|europeo,NOUN': 30,
#  'VERB|trata,SCONJ': 3,
#  'VERB|incentivar,ADP': 2,
#  'NOUN|mercado,DET': 83,
#  'PRON|donde,NOUN': 76,
#  'ADV|no,PRON': 400,
#  'PRON|lo,ADV': 122,
#  'AUX|hay,PRON': 44,
#  'PUNCT|.,AUX': 17,
#  'DET|la,None': 1274,
#  'NOUN|inversión,DET': 34,
#  'ADP|en,NOUN': 2968,
#  'NOUN|investigación,ADP': 24,
#  'ADJ|básica,NOUN': 9,
#  'AUX|es,ADJ': 154,
#  'DET|el,AUX': 405,
#  'NOUN|camino,DET': 28,
#  'ADP|para,NOUN': 1140,
#  'DET|el,ADP': 4513,
#  'NOUN|crecimiento,DET': 38,
#  'DET|la,CCONJ': 603,
#  'NOUN|prosperidad,DET': 7,
#  'ADJ|económica,NOUN': 53,
#  'PUNCT|,,ADJ': 3302,
#  'VERB|afirmaron,PUNCT': 2,
#  'ADV|hoy,VERB': 450,
#  'NOUN|empresarios,ADV': 1,
#  'PUNCT|,,NOUN': 8456,
#  'DET|el,PUNCT': 1484,
#  'NOUN|embajador,DET': 7,
#  'PROPN|eeuu,ADP': 90,
#  'CCONJ|y,PROPN': 1896,
#  'DET|el,CCONJ': 698,
#  'NOUN|director,DET': 57,
#  'PROPN|comunidad,DET': 33,
#  'PROPN|madrid,ADP': 179,
#  'PRON|quienes,PUNCT': 11,
#  'VERB|abogaron,PRON': 1,
#  'ADP|por,VERB': 741,
#  'VERB|elevar,ADP': 5,
#  'PUNCT|",DET': 386,
#  'NOUN|cultura,PUNCT': 5,
#  'ADJ|científica,NOUN': 7,
#  'PUNCT|",ADJ': 1115,
#  'ADP|de,PUNCT': 747,
#  'NOUN|ciudadanos,DET': 45,
#  'NOUN|innovación,DET': 5,
#  'PUNCT|",NOUN': 1921,
#  'NOUN|empresarios,DET': 19,
#  'ADP|durante,None': 43,
#  'NOUN|presentación,DET': 17,
#  'NOUN|libro,ADP': 4,
#  'DET|la,PUNCT': 1033,
#  'PROPN|prosperidad,DET': 1,
#  'ADP|por,PROPN': 173,
#  'PROPN|medio,ADP': 10,
#  'PROPN|investigación,DET': 2,
#  'PUNCT|.,PROPN': 2639,
#  'PROPN|básica,PROPN': 1,
#  'ADP|en,PROPN': 685,
#  'PUNCT|",PROPN': 642,
#  'PUNCT|,,PUNCT': 1950,
#  'ADJ|editado,PUNCT': 2,
#  'ADP|por,ADJ': 959,
#  'NOUN|secretario,DET': 64,
#  'ADJ|general,NOUN': 134,
#  'PROPN|confederación,DET': 7,
#  'PROPN|empresarial,PROPN': 1,
#  'PROPN|madrid-ceoe,ADP': 1,
#  'PUNCT|(,PROPN': 894,
#  'PROPN|ceim,PUNCT': 1,
#  'PUNCT|),PROPN': 772,
#  'PROPN|alejandro,PUNCT': 7,
#  'PROPN|couceiro,PROPN': 1,
#  'VERB|abogó,PUNCT': 4,
#  'NOUN|formación,DET': 64,
#  'NOUN|investigadores,DET': 6,
#  'NOUN|temas,ADP': 7,
#  'NOUN|innovación,ADP': 2,
#  'ADJ|tecnológica,NOUN': 7,
#  'PUNCT|.,ADJ': 2487,
#  'ADP|tras,None': 71,
#  'VERB|indicar,ADP': 3,
#  'DET|la,SCONJ': 793,
#  'ADJ|media,NOUN': 7,
#  'ADP|en,ADJ': 1428,
#  'PROPN|unión,DET': 79,
#  'PROPN|europea,PROPN': 90,
#  'VERB|sitúa,PRON': 11,
#  'ADP|en,VERB': 2558,
#  'NUM|1,8,DET': 2,
#  'ADP|por,NUM': 415,
#  'NUM|ciento,ADP': 388,
#  'ADP|del,NUM': 63,
#  'PROPN|pib,ADP': 9,
#  'NOUN|frente,PUNCT': 29,
#  'ADP|al,NOUN': 650,
#  'NUM|2,8,ADP': 2,
#  'ADP|en,NUM': 107,
#  'PROPN|japón,ADP': 26,
#  'PROPN|eeuu,CCONJ': 7,
#  'PROPN|couceiro,PUNCT': 1,
#  'PROPN|españa,SCONJ': 22,
#  'AUX|está,PROPN': 61,
#  'ADP|en,AUX': 137,
#  'PUNCT|",ADP': 345,
#  'ADJ|buen,DET': 47,
#  'NOUN|camino,ADJ': 10,
#  'CCONJ|y,PUNCT': 1547,
#  'PRON|se,CCONJ': 230,
#  'AUX|está,PRON': 99,
#  'VERB|creando,AUX': 5,
#  'DET|un,VERB': 1120,
#  'NOUN|entorno,DET': 16,
#  'ADJ|propicio,NOUN': 2,
#  'ADP|para,ADJ': 608,
#  'ADJ|empresarial,NOUN': 12,
#  'ADP|en,None': 758,
#  'DET|este,ADP': 371,
#  'NOUN|sentido,DET': 64,
#  'PRON|se,NOUN': 823,
#  'VERB|refirió,PRON': 17,
#  'ADJ|reciente,DET': 15,
#  'NOUN|creación,ADJ': 1,
#  'PROPN|ministerio,ADP': 21,
#  'PROPN|ciencia,ADP': 4,
#  'PROPN|tecnología,CCONJ': 5,
#  'ADJ|primeras,DET': 25,
#  'NOUN|declaraciones,ADJ': 8,
#  'DET|su,ADP': 1557,
#  'NOUN|titular,DET': 25,
#  'PROPN|anna,PUNCT': 4,
#  'PROPN|birulés,PROPN': 6,
#  'ADP|sobre,PUNCT': 86,
#  'NOUN|impulso,DET': 7,
#  'NOUN|investigación,DET': 49,
#  'NOUN|desarrollo,PUNCT': 1,
#  'CCONJ|e,NOUN': 90,
#  'NOUN|innovación,CCONJ': 2,
#  'NOUN|representante,DET': 25,
#  'ADJ|madrileños,NOUN': 2,
#  'VERB|aseguró,ADJ': 9,
#  'PUNCT|",SCONJ': 410,
#  'NOUN|siglo,DET': 20,
#  'NOUN|xxi,NOUN': 5,
#  'AUX|será,NOUN': 53,
#  'NOUN|ciencia,DET': 14,
#  'NOUN|tecnología,DET': 16,
#  'VERB|ofreció,CCONJ': 2,
#  'NOUN|apoyo,DET': 55,
#  'ADJ|activo,PUNCT': 3,
#  'PROPN|ceim,DET': 1,
#  'NOUN|consecución,DET': 9,
#  'NOUN|retos,DET': 5,
#  'ADJ|fijados,NOUN': 4,
#  'PROPN|gobierno,DET': 230,
#  'DET|esta,ADP': 276,
#  'NOUN|materia,DET': 16,
#  'ADJ|estadounidense,NOUN': 44,
#  'PROPN|españa,ADP': 255,
#  'PROPN|edward,PUNCT': 1,
#  'PROPN|romero,PROPN': 7,
#  'VERB|aseguró,PUNCT': 64,
#  'VERB|contribuye,ADJ': 3,
#  'VERB|destacó,CCONJ': 8,
#  'NOUN|colaboración,DET': 17,
#  'ADP|entre,NOUN': 270,
#  'PROPN|estados,CCONJ': 6,
#  'PROPN|unidos,PROPN': 122,
#  'NOUN|campo,DET': 40,
#  'ADJ|materializada,PUNCT': 1,
#  'DET|diversos,ADP': 14,
#  'NOUN|acuerdos,DET': 20,
#  'NOUN|libro,DET': 36,
#  'ADJ|presentado,NOUN': 7,
#  'ADV|hoy,ADJ': 32,
#  'VERB|recoge,ADV': 3,
#  'NOUN|forma,ADP': 106,
#  'ADJ|resumida,NOUN': 1,
#  'DET|un,ADJ': 24,
#  'NOUN|informe,DET': 41,
#  'PROPN|comité,ADP': 25,
#  'PROPN|desarrollo,ADP': 8,
#  'PROPN|económico,PROPN': 7,
#  'ADP|en,PUNCT': 1260,
#  'PRON|que,DET': 921,
#  'PRON|se,PRON': 884,
#  'VERB|destaca,PRON': 4,
#  'NOUN|importancia,DET': 21,
#  'ADJ|universitaria,ADJ': 2,
#  'ADJ|americana,ADJ': 1,
#  'VERB|propone,CCONJ': 1,
#  'VERB|mejorar,VERB': 4,
#  'NOUN|enseñanza,DET': 5,
#  'VERB|asegurar,ADP': 24,
#  'NOUN|provisión,DET': 2,
#  'ADJ|futura,NOUN': 2,
#  'NOUN|científicos,ADP': 4,
#  'ADJ|sobresalientes,NOUN': 1,
#  'ADV|asimismo,None': 26,
#  'VERB|defiende,ADV': 4,
#  'NOUN|financiación,DET': 20,
#  'ADJ|pública,NOUN': 61,
#  'VERB|pone,CCONJ': 2,
#  'NOUN|manifiesto,ADP': 8,
#  'SCONJ|que,NOUN': 450,
#  'DET|las,SCONJ': 223,
#  'NOUN|empresas,DET': 72,
#  'VERB|centran,PRON': 4,
#  'ADV|más,VERB': 237,
#  'ADP|en,ADV': 440,
#  'CCONJ|i,DET': 1,
#  'PROPN|+,CCONJ': 3,
#  'PROPN|d,PROPN': 5,
#  'ADP|con,PROPN': 188,
#  'NOUN|objetivos,ADP': 4,
#  'NOUN|mercado,ADP': 60,
#  'DET|este,None': 68,
#  'NOUN|documento,DET': 28,
#  'PRON|que,PUNCT': 1584,
#  'AUX|ha,PRON': 625,
#  'VERB|tomado,AUX': 7,
#  'ADP|como,VERB': 3,
#  'NOUN|referencia,ADP': 21,
#  'DET|la,NOUN': 284,
#  'VERB|hace,PUNCT': 22,
#  'NOUN|hincapié,VERB': 5,
#  'SCONJ|que,ADP': 1112,
#  'DET|los,SCONJ': 365,
#  'NOUN|retornos,DET': 2,
#  'ADJ|económicos,NOUN': 28,
#  'NOUN|inversiones,DET': 27,
#  'AUX|son,ADJ': 23,
#  'PUNCT|",AUX': 157,
#  'ADV|muy,PUNCT': 62,
#  'ADJ|elevados,ADV': 2,
#  'NOUN|conocimiento,DET': 11,
#  'ADJ|básico,NOUN': 6,
#  'VERB|tiende,ADJ': 1,
#  'AUX|ser,ADP': 207,
#  'VERB|explotado,AUX': 1,
#  'NOUN|innovaciones,ADP': 1,
#  'VERB|producen,PRON': 14,
#  'ADJ|sustanciales,VERB': 1,
#  'NOUN|beneficios,ADJ': 5,
#  'ADP|durante,NOUN': 74,
#  'DET|un,ADP': 1658,
#  'ADJ|largo,DET': 12,
#  'NOUN|periodo,ADJ': 9,
#  'PUNCT|.,PUNCT': 1722,
#  'ADP|para,None': 136,
#  'PROPN|investigación,ADP': 4,
#  'PROPN|cam,DET': 1,
#  'PROPN|francisco,PUNCT': 20,
#  'PROPN|josé,PROPN': 26,
#  'PROPN|rubia,PROPN': 1,
#  'AUX|es,PUNCT': 316,
#  'ADJ|necesario,AUX': 33,
#  'VERB|apoyar,ADJ': 1,
#  'NOUN|fondo,ADP': 23,
#  'NOUN|calidad,ADP': 14,
#  'VERB|incentivar,CCONJ': 1,
#  'ADP|con,VERB': 985,
#  'DET|diferentes,ADP': 20,
#  'NOUN|científicos,DET': 15,
#  'NOUN|técnicos,CCONJ': 1,
#  'NOUN|sector,DET': 55,
#  'ADJ|productivo,NOUN': 2,
#  'NOUN|portavoz,DET': 89,
#  'PROPN|pp,ADP': 109,
#  'PROPN|rafael,PUNCT': 11,
#  'PROPN|hernando,PROPN': 1,
#  'VERB|dijo,PUNCT': 253,
#  'ADP|a,ADV': 347,
#  'PROPN|efe,ADP': 80,
#  'SCONJ|que,PROPN': 136,
#  'NOUN|agentes,DET': 32,
#  'ADJ|sociales,NOUN': 43,
#  'AUX|deben,ADJ': 4,
#  'VERB|acudir,AUX': 2,
#  'NOUN|mentalidad,ADP': 1,
#  'ADJ|abierta,PUNCT': 3,
#  'ADP|sin,CCONJ': 45,
#  'NOUN|planteamientos,ADP': 3,
#  'ADJ|preconcebidos,PUNCT': 1,
#  'ADP|a,PUNCT': 576,
#  'NOUN|cita,DET': 20,
#  'NOUN|tarde,DET': 53,
#  'PROPN|gobierno,ADP': 236,
#  'PROPN|josé,PUNCT': 79,
#  'PROPN|maría,PROPN': 74,
#  'PROPN|aznar,PROPN': 38,
#  'PROPN|hernando,None': 2,
#  'VERB|fundamentó,PROPN': 2,
#  'DET|tales,VERB': 3,
#  'NOUN|premisas,DET': 4,
#  'PRON|se,SCONJ': 463,
#  'VERB|trata,PRON': 72,
#  'VERB|defender,ADP': 22,
#  'DET|los,VERB': 689,
#  'ADJ|generales,NOUN': 33,
#  'NOUN|españoles,DET': 17,
#  'ADV|máxime,PUNCT': 2,
#  'VERB|teniendo,ADV': 2,
#  'NOUN|cuenta,ADP': 50,
#  'AUX|es,PROPN': 214,
#  'NOUN|país,DET': 235,
#  'PRON|que,PROPN': 179,
#  'ADV|más,PRON': 113,
#  'NOUN|empleo,ADV': 4,
#  'AUX|ha,NOUN': 202,
#  'VERB|creado,AUX': 18,
#  'CCONJ|y,VERB': 346,
#  'PRON|que,CCONJ': 200,
#  'VERB|registra,PRON': 6,
#  'ADJ|mayor,VERB': 8,
#  'NOUN|crecimiento,ADJ': 5,
#  'ADJ|económico,NOUN': 50,
#  'NOUN|opinión,DET': 58,
#  'DET|un,AUX': 388,
#  'NOUN|hecho,DET': 54,
#  'ADJ|gran,PUNCT': 17,
#  'NOUN|relevancia,ADJ': 3,
#  'NOUN|reunión,DET': 84,
#  'VERB|celebrará,PRON': 16,
#  'PROPN|aznar,VERB': 9,
#  'NOUN|dirigente,DET': 31,
#  'NOUN|patronal,DET': 22,
#  'PROPN|ceoe,NOUN': 2,
#  'PROPN|cuevas,PROPN': 5,
#  'ADP|con,CCONJ': 148,
#  'ADP|de,DET': 251,
#  'PROPN|ccoo,ADP': 17,
#  'PROPN|fidalgo,PROPN': 4,
#  'PROPN|ugt,CCONJ': 5,
#  'PROPN|cándido,PUNCT': 6,
#  'PROPN|méndez,PROPN': 8,
#  'VERB|añadió,None': 9,
#  'DET|el,SCONJ': 1095,
#  'NOUN|interés,DET': 22,
#  'PROPN|aznar,ADP': 26,
#  '_|entrevistarse,ADP': 3,
#  'VERB|entrevistar,_': 4,
#  'PRON|se,VERB': 851,
#  'ADP|con,PRON': 109,
#  'ADJ|máximos,DET': 9,
#  'NOUN|representantes,ADJ': 3,
#  'ADJ|empresariales,NOUN': 10,
#  'ADJ|sindicales,CCONJ': 2,
#  'DET|una,AUX': 254,
#  'NOUN|muestra,DET': 14,
#  'NOUN|talante,DET': 7,
#  'VERB|seguir,ADP': 31,
#  'NOUN|proceso,DET': 92,
#  'NOUN|diálogo,ADP': 18,
#  'ADJ|social,NOUN': 71,
#  'PUNCT|",PUNCT': 495,
#  'NOUN|eje,PUNCT': 2,
#  'NOUN|política,DET': 104,
#  'ADV|tan,PRON': 13,
#  'ADJ|buenos,ADV': 5,
#  'NOUN|resultados,ADJ': 12,
#  'AUX|ha,PUNCT': 253,
#  'VERB|tenido,AUX': 73,
#  'ADP|para,VERB': 292,
#  'NOUN|empleo,DET': 19,
#  'PROPN|seguridad,DET': 15,
#  'PROPN|social,PROPN': 27,
#  'VERB|destacó,PROPN': 22,
#  'NOUN|reforma,DET': 50,
#  'ADJ|laboral,NOUN': 51,
#  'NOUN|1997,ADP': 33,
#  'NOUN|fruto,PUNCT': 3,
#  'ADJ|alcanzados,NOUN': 1,
#  'ADP|con,ADJ': 407,
#  'VERB|tuvo,PUNCT': 14,
#  'NOUN|efectos,VERB': 8,
#  'ADJ|extraordinarios,PUNCT': 1,
#  'VERB|sirvió,CCONJ': 3,
#  'VERB|frenar,ADP': 11,
#  'ADJ|desbocado,PUNCT': 1,
#  'NOUN|inestabilidad,DET': 7,
#  'PRON|que,ADJ': 654,
#  'VERB|produjo,PRON': 47,
#  'NOUN|partir,ADP': 90,
#  'NOUN|1986,ADP': 8,
#  'ADV|además,None': 115,
#  'ADP|de,ADV': 1118,
#  'VERB|acabar,ADP': 19,
#  'NOUN|contratos,DET': 16,
#  'NOUN|basura,PUNCT': 1,
#  'VERB|señaló,PROPN': 29,
#  'ADJ|dicha,SCONJ': 2,
#  'NOUN|reforma,ADJ': 6,
#  'VERB|introdujo,NOUN': 3,
#  'NOUN|sistema,DET': 84,
#  'NOUN|ayudas,ADP': 3,
#  'NOUN|contratación,DET': 11,
#  'ADJ|indefinida,NOUN': 2,
#  'ADV|así,PUNCT': 87,
#  'SCONJ|como,ADV': 108,
#  'NOUN|remodelación,DET': 3,
#  'NOUN|contrato,ADP': 8,
#  'ADJ|estable,NOUN': 8,
#  'NOUN|tiempo,ADP': 47,
#  'ADJ|parcial,NOUN': 18,
#  'VERB|mejorado,AUX': 5,
#  'DET|las,VERB': 616,
#  'NOUN|relaciones,DET': 44,
#  'ADJ|laborales,NOUN': 20,
#  'ADP|a,None': 206,
#  'NOUN|juicio,ADP': 20,
#  'PROPN|hernando,ADP': 1,
#  'VERB|seguir,ADJ': 1,
#  'VERB|avanzando,VERB': 1,
#  'NOUN|fin,ADP': 49,
#  'VERB|crear,ADP': 25,
#  'VERB|rebajar,PUNCT': 1,
#  'NOUN|tasa,DET': 30,
#  'NOUN|temporalidad,ADP': 1,
#  'VERB|combatir,CCONJ': 3,
#  'NOUN|siniestralidad,DET': 10,
#  'NOUN|trabajo,DET': 72,
#  'PROPN|komercni,DET': 2,
#  'PROPN|banka,PROPN': 3,
#  'PROPN|banco,PUNCT': 2,
#  'PROPN|comercial,PROPN': 6,
#  'PRON|uno,PUNCT': 50,
#  'ADP|de,PRON': 611,
#  'NUM|cuatro,DET': 49,
#  'NOUN|bancos,NUM': 2,
#  'ADV|más,NOUN': 420,
#  'ADJ|grandes,ADV': 5,
#  'PROPN|república,DET': 20,
#  'PROPN|checa,PROPN': 7,
#  'VERB|anunció,PUNCT': 40,
#  'SCONJ|que,ADV': 532,
#  'VERB|despedirá,SCONJ': 2,
#  'NUM|2.300,ADP': 1,
#  'NOUN|empleados,NUM': 12,
#  'ADV|antes,ADV': 23,
#  'NOUN|finales,ADP': 31,
#  'NOUN|año,ADP': 113,
#  'ADV|dentro,NOUN': 23,
#  'ADP|del,ADV': 215,
#  'NOUN|proceso,ADP': 14,
#  'NOUN|saneamiento,ADP': 3,
#  'NOUN|entidad,DET': 40,
#  'ADJ|estatal,NOUN': 16,
#  'NOUN|banco,ADP': 17,
#  'PROPN|radovan,PUNCT': 1,
#  'PROPN|vrava,PROPN': 1,
#  'VERB|señaló,PUNCT': 64,
#  'NOUN|motivo,DET': 16,
#  'ADJ|principal,NOUN': 21,
#  'DET|la,AUX': 313,
#  'NOUN|reestructuración,DET': 5,
#  'ADV|no,CCONJ': 285,
#  'ADV|sólo,ADV': 24,
#  'DET|la,ADV': 265,
#  'NOUN|reducción,DET': 30,
#  'NOUN|costes,DET': 13,
#  'PROPN|estado,DET': 41,
#  'VERB|dispone,PROPN': 2,
#  'ADP|del,VERB': 174,
#  'NUM|60,ADP': 23,
#  'ADP|de,NUM': 683,
#  'NOUN|acciones,DET': 34,
#  'PROPN|komercni,ADP': 1,
#  'ADJ|checo,PROPN': 2,
#  'VERB|quiere,ADJ': 7,
#  'VERB|comenzar,VERB': 1,
#  'NOUN|privatización,ADP': 4,
#  'NOUN|banco,DET': 18,
#  'ADV|ya,NOUN': 80,
#  'NOUN|año,DET': 257,
#  '_|terminarlo,CCONJ': 1,
#  'VERB|terminar,_': 1,
#  'PRON|lo,VERB': 278,
#  'ADP|en,PRON': 350,
#  'NOUN|septiembre,ADP': 49,
#  'NUM|2001,ADP': 11,
#  'PUNCT|.,NUM': 190,
#  'PRON|otro,None': 2,
#  'NOUN|objetivos,DET': 16,
#  'VERB|evitar,AUX': 9,
#  'VERB|repitan,PRON': 3,
#  'NOUN|errores,DET': 11,
#  'NOUN|pasado,ADP': 19,
#  'VERB|obligaron,PRON': 3,
#  'ADP|al,VERB': 866,
#  'VERB|comprar,ADP': 10,
#  'NOUN|créditos,VERB': 1,
#  'ADJ|dudosos,NOUN': 1,
#  'NOUN|valor,DET': 39,
#  'NUM|60.000,ADP': 1,
#  'NOUN|millones,NUM': 490,
#  'NOUN|coronas,ADP': 4,
#  'PUNCT|(,NOUN': 333,
#  'PRON|unos,PUNCT': 18,
#  'NUM|1.500,PRON': 1,
#  'NOUN|dólares,ADP': 110,
#  'PUNCT|),NOUN': 369,
#  'PRON|esto,None': 21,
#  'VERB|permitirá,PRON': 9,
#  'VERB|sanear,NOUN': 1,
#  'DET|su,VERB': 643,
#  'NOUN|portafolio,DET': 2,
#  'AUX|es,PRON': 259,
#  'NOUN|condición,AUX': 2,
#  'VERB|continuar,ADP': 12,
#  'NOUN|privatización,DET': 5,
#  'ADJ|nueva,DET': 149,
#  'NOUN|dirección,ADJ': 3,
#  'AUX|está,NOUN': 68,
#  'VERB|trabajando,AUX': 6,
#  'VERB|recuperar,ADP': 16,
#  'NOUN|prestigio,DET': 3,
#  'NOUN|institución,DET': 19,
#  'ADJ|debido,NOUN': 16,
#  'ADP|al,ADJ': 279,
#  'NOUN|escándalo,ADP': 4,
#  'ADP|por,NOUN': 790,
#  'NOUN|violación,DET': 5,
#  'NOUN|límites,DET': 6,
#  'NOUN|crédito,ADP': 15,
#  'DET|sus,ADP': 538,
#  'NOUN|negocios,DET': 7,
#  'ADJ|austriacas,NOUN': 3,
#  'PROPN|c.,ADJ': 1,
#  'PROPN|l.,PROPN': 4,
#  'PROPN|tradung,PROPN': 1,
#  'PRON|otras,CCONJ': 13,
#  'PUNCT|,,PRON': 663,
#  'VERB|supusieron,PRON': 2,
#  'NOUN|pérdidas,VERB': 4,
#  'PRON|unos,ADP': 44,
#  'NUM|200,PRON': 4,
#  'DET|el,NOUN': 361,
#  'NOUN|pasado,NOUN': 22,
#  'DET|ese,None': 17,
#  'NOUN|escándalo,DET': 15,
#  'VERB|provocó,NOUN': 6,
#  'ADJ|amplios,VERB': 1,
#  'NOUN|cambios,ADJ': 3,
#  'NOUN|directivos,ADP': 4,
#  'DET|todos,ADP': 107,
#  'DET|los,DET': 184,
#  'NOUN|niveles,DET': 6,
#  'ADP|desde,PUNCT': 69,
#  'NOUN|presidente,CCONJ': 7,
#  'PROPN|jan,NOUN': 1,
#  'PROPN|kollert,PROPN': 1,
#  'DET|otros,CCONJ': 40,
#  'NOUN|miembros,DET': 40,
#  'NOUN|dirección,DET': 54,
#  'ADP|hasta,NOUN': 97,
#  'NOUN|personal,ADP': 9,
#  'ADJ|medio,NOUN': 8,
#  'VERB|tenía,PROPN': 10,
#  'DET|una,VERB': 930,
#  'NOUN|plantilla,DET': 35,
#  'NUM|13.487,ADP': 1,
#  'NOUN|fines,ADP': 6,
#  'NOUN|1999,ADP': 76,
#  'NUM|470,PUNCT': 1,
#  'AUX|fueron,NUM': 8,
#  'VERB|despedidos,AUX': 1,
#  'ADP|durante,VERB': 67,
#  'ADJ|primer,DET': 188,
#  'NOUN|trimestre,ADJ': 15,
#  'ADJ|presente,ADP': 2,
#  'NOUN|año,ADJ': 58,
#  'PRON|otros,CCONJ': 18,
#  'NUM|170,PRON': 1,
#  'NOUN|funcionarios,NUM': 3,
#  'AUX|fueron,NOUN': 45,
#  'VERB|trasladados,AUX': 7,
#  'DET|una,ADP': 1144,
#  'NOUN|filial,DET': 21,
#  'DET|otros,DET': 16,
#  'NOUN|bancos,DET': 14,
#  'ADJ|checos,NOUN': 1,
#  'PRON|se,ADJ': 202,
#  'VERB|acompañando,AUX': 1,
#  'PROPN|caja,DET': 8,
#  'PROPN|ahorros,ADP': 3,
#  'ADV|ya,PUNCT': 249,
#  'ADJ|comprada,ADV': 1,
#  'PROPN|erste,DET': 1,
#  'PROPN|basnk,PROPN': 1,
#  'PROPN|austria,ADP': 14,
#  'VERB|reducido,AUX': 10,
#  'ADP|desde,NOUN': 78,
#  'NUM|18.700,ADP': 1,
#  'NOUN|1996,ADP': 23,
#  'ADJ|actuales,DET': 7,
#  'NUM|15.100,ADJ': 1,
#  'CCONJ|y,NUM': 156,
#  'VERB|tiene,CCONJ': 17,
#  'ADJ|planeado,VERB': 1,
#  '_|reducirlo,ADJ': 1,
#  'VERB|reducir,_': 3,
#  'ADP|a,PRON': 265,
#  'NUM|14.000,ADP': 2,
#  'ADV|antes,NUM': 2,
#  'ADV|también,None': 103,
#  'DET|el,ADV': 310,
#  'PROPN|banco,DET': 42,
#  'PROPN|checoslovaco,PROPN': 1,
#  'PROPN|csob,PUNCT': 1,
#  'ADJ|adquirido,PUNCT': 1,
#  'ADJ|belga,NOUN': 3,
#  'PROPN|kbc,ADJ': 1,
#  'PROPN|inversiones,ADP': 3,
#  'PROPN|postal,CCONJ': 1,
#  'PROPN|ipb,PUNCT': 1,
#  'PUNCT|(,PUNCT': 35,
#  'PROPN|nomura,ADP': 1,
#  'VERB|preparan,PUNCT': 1,
#  'ADJ|moderada,NOUN': 2,
#  'NOUN|plantillas,DET': 2,
#  'NOUN|plantilla,ADP': 4,
#  'ADJ|últimos,DET': 148,
#  'NUM|dos,ADJ': 10,
#  'NOUN|años,NUM': 530,
#  'DET|estos,ADP': 94,
#  'AUX|sido,AUX': 329,
#  'ADP|de,AUX': 189,
#  'ADV|alrededor,ADP': 3,
#  'NUM|8.000,ADP': 4,
#  'CCONJ|pero,PUNCT': 670,
#  'VERB|siguen,CCONJ': 3,
#  'VERB|teniendo,VERB': 3,
#  'ADV|poco,DET': 28,
#  'ADV|menos,ADV': 21,
#  'NUM|50.000,ADP': 5,
#  'NOUN|empresa,DET': 160,
#  'ADJ|canadiense,NOUN': 5,
#  'PROPN|alcan,ADJ': 1,
#  'PROPN|aluminium,PROPN': 1,
#  'VERB|anunció,PROPN': 34,
#  'NOUN|jueves,DET': 27,
#  'AUX|ha,SCONJ': 60,
#  'VERB|llegado,AUX': 36,
#  'NOUN|acuerdo,DET': 101,
#  'NOUN|principio,ADP': 38,
#  'NOUN|fusión,DET': 32,
#  'ADJ|suiza,DET': 1,
#  'PROPN|algroup,ADJ': 1,
#  'VERB|establece,PRON': 8,
#  'NOUN|cambio,DET': 49,
#  'NUM|17.1,ADP': 1,
#  'NOUN|acciones,NUM': 2,
#  'PROPN|alcan,ADP': 4,
#  'DET|cada,ADP': 62,
#  'PRON|una,DET': 16,
#  'ADJ|helvética,NOUN': 1,
#  'ADV|también,NOUN': 64,
#  'VERB|supone,ADV': 7,
#  'NOUN|accionistas,DET': 6,
#  'VERB|recibirán,NOUN': 1,
#  'NOUN|pago,DET': 10,
#  'NOUN|capital,ADP': 18,
#  'NUM|90,ADP': 6,
#  'NOUN|francos,NUM': 4,
#  'ADJ|suizos,NOUN': 6,
#  'PUNCT|(,ADJ': 157,
#  'NUM|53,PUNCT': 1,
#  'NOUN|dólares,NUM': 60,
#  'DET|un,CCONJ': 145,
#  'NOUN|dividendo,DET': 2,
#  'ADJ|especial,NOUN': 35,
#  'NUM|135,ADP': 1,
#  'NUM|80,PRON': 6,
#  'ADP|por,PUNCT': 526,
#  'NOUN|acción,DET': 39,
#  'PROPN|algroup,ADP': 6,
#  'AUX|estará,ADJ': 1,
#  'ADJ|condicionado,AUX': 1,
#  'NOUN|entrega,DET': 9,
#  'NOUN|intercambio,DET': 11,
#  'ADP|del,PROPN': 440,
#  'NUM|67,ADP': 2,
#  'NOUN|circulación,ADP': 10,
#  'ADP|de,None': 142,
#  '_|llevarse,ADP': 1,
#  'VERB|llevar,_': 14,
#  'NOUN|cabo,ADP': 66,
#  'VERB|creará,NOUN': 1,
#  'NOUN|sociedad,DET': 95,
#  'NOUN|ingresos,ADP': 8,
#  'ADJ|combinados,NOUN': 2,
#  'NUM|12.400,ADP': 1,
#  'ADV|mientras,NOUN': 1,
#  'NOUN|beneficios,DET': 24,
#  'ADJ|inmediatos,ADJ': 1,
#  'VERB|supondrán,ADJ': 1,
#  'ADV|menos,ADP': 70,
#  'DET|un,ADV': 122,
#  'NOUN|ahorro,DET': 5,
#  'NUM|150,ADP': 7,
#  'VERB|conseguido,AUX': 43,
#  'ADV|después,VERB': 30,
#  'PROPN|alcan,SCONJ': 1,
#  'VERB|asegurase,PRON': 1,
#  'PROPN|bz,ADP': 1,
#  'PROPN|group,PROPN': 2,
#  'PROPN|holding,PROPN': 4,
#  'PROPN|limited,PROPN': 2,
#  'ADJ|principales,DET': 49,
#  'NOUN|accionistas,ADJ': 4,
#  'PROPN|bz,None': 1,
#  'VERB|proporcionará,PROPN': 1,
#  'NUM|34,DET': 2,
#  'ADP|para,PROPN': 291,
#  'NOUN|través,ADP': 69,
#  'NOUN|comunicado,DET': 56,
#  'NOUN|prensa,ADP': 63,
#  'PROPN|jacques,PUNCT': 3,
#  'PROPN|bougie,PROPN': 1,
#  'AUX|estoy,PUNCT': 14,
#  'ADJ|seguro,AUX': 9,
#  'SCONJ|que,ADJ': 341,
#  'DET|esta,SCONJ': 36,
#  'VERB|proporcionará,NOUN': 1,
#  'ADJ|significante,DET': 1,
#  'NOUN|valor,ADJ': 10,
#  'VERB|espero,CCONJ': 4,
#  'VERB|fusionar,VERB': 1,
#  'NOUN|operaciones,DET': 25,
#  'PROPN|alcan,CCONJ': 1,
#  'NOUN|industria,ADJ': 3,
#  'NOUN|líder,NOUN': 2,
#  'NOUN|nivel,ADP': 19,
#  'ADJ|global,NOUN': 14,
#  'NOUN|aluminio,ADP': 5,
#  'NOUN|embalado,DET': 1,
#  'ADP|por,None': 211,
#  'NOUN|parte,DET': 116,
#  'ADJ|ejecutivo,NOUN': 15,
#  'PROPN|sergio,PUNCT': 4,
#  'PROPN|marchionne,PROPN': 1,
#  'NOUN|compañía,ADJ': 7,
#  'AUX|estará,NOUN': 9,
#  'ADJ|mejor,ADP': 7,
#  'NOUN|posición,ADJ': 10,
#  'VERB|servir,ADP': 3,
#  'NOUN|necesidades,DET': 13,
#  'PROPN|alcan,None': 1,
#  'PRON|una,AUX': 22,
#  'ADJ|mayores,DET': 18,
#  'NOUN|empresas,ADJ': 21,
#  'NOUN|mundo,ADP': 93,
#  'ADJ|dedicada,NOUN': 8,
#  'NOUN|producción,DET': 51,
#  'VERB|cuenta,None': 2,
#  'NOUN|operaciones,ADP': 16,
#  'NUM|30,ADP': 32,
#  'NOUN|países,NUM': 60,
#  'VERB|emplea,CCONJ': 1,
#  'NUM|30.000,ADP': 2,
#  'NOUN|personas,NUM': 106,
#  'NOUN|productos,CCONJ': 4,
#  'ADJ|derivados,NOUN': 3,
#  'PROPN|algroup,None': 1,
#  'ADJ|presente,PUNCT': 2,
#  'NUM|18,ADP': 24,
#  'NUM|23.000,ADP': 2,
#  'VERB|opera,PUNCT': 1,
#  'NOUN|empaquetado,DET': 1,
#  'ADP|con,PUNCT': 482,
#  'ADJ|fuerte,DET': 33,
#  'NOUN|presencia,ADJ': 8,
#  'NOUN|industria,DET': 26,
#  'NOUN|transporte,ADP': 23,
#  'ADP|del,CCONJ': 95,
#  'NOUN|embalaje,ADP': 1,
#  'NOUN|productos,ADP': 20,
#  'ADJ|alimentarios,NOUN': 1,
#  'ADJ|cosméticos,PUNCT': 1,
#  'ADJ|farmacéuticos,CCONJ': 1,
#  'NOUN|consumo,DET': 20,
#  'NOUN|café,ADP': 45,
#  'PROPN|alemania,ADP': 28,
#  'VERB|aumentó,PROPN': 3,
#  'ADV|cerca,VERB': 23,
#  'NUM|2,ADP': 4,
#  'ADP|según,PUNCT': 212,
#  'NOUN|estadísticas,DET': 9,
#  'ADJ|anuales,NOUN': 15,
#  'PROPN|kraft,NOUN': 1,
#  'PROPN|foods,PROPN': 5,
#  'PROPN|bremen,ADP': 3,
#  'ADP|sin,None': 100,
#  'NOUN|embargo,ADP': 155,
#  'PRON|lo,ADP': 419,
#  'NOUN|largo,PRON': 37,
#  'NOUN|década,DET': 11,
#  'NOUN|noventa,DET': 1,
#  'VERB|registró,PRON': 6,
#  'NOUN|descenso,DET': 14,
#  'VERB|calcula,PRON': 9,
#  'ADP|entre,VERB': 90,
#  'NUM|1,DET': 6,
#  'NUM|2,DET': 17,
#  'ADV|actualmente,None': 4,
#  'PUNCT|,,ADV': 1000,
#  'DET|los,PUNCT': 422,
#  'NOUN|alemanes,DET': 14,
#  'VERB|toman,NOUN': 1,
#  'NOUN|promedio,DET': 8,
#  'NUM|6,7,ADP': 2,
#  'NOUN|kilos,NUM': 22,
#  'NOUN|persona,ADP': 5,
#  'DET|los,None': 590,
#  'NOUN|bebedores,ADJ': 1,
#  'PROPN|europa,ADP': 92,
#  'VERB|siguen,PROPN': 4,
#  'AUX|siendo,VERB': 35,
#  'DET|los,AUX': 89,
#  'NOUN|escandinavos,DET': 1,
#  'ADV|cerca,ADP': 15,
#  'NUM|12,ADP': 24,
#  'CCONJ|mientras,NOUN': 2,
#  'ADV|más,DET': 148,
#  'ADJ|reservados,ADV': 2,
#  'NOUN|portugueses,DET': 1,
#  'ADV|apenas,ADP': 15,
#  'NUM|4,1,ADV': 1,
#  'NOUN|cabeza,ADP': 17,
#  'ADP|entre,None': 56,
#  'NUM|5,DET': 10,
#  'NUM|6,DET': 10,
#  'NOUN|junio,ADP': 71,
#  'VERB|encontrarán,PRON': 2,
#  'ADV|cerca,PROPN': 1,
#  'NUM|200,ADP': 11,
#  'NOUN|expertos,NUM': 5,
#  'PROPN|sudamérica,CCONJ': 1,
#  'PROPN|xii,DET': 2,
#  'PROPN|congreso,PROPN': 3,
#  'PROPN|europeo,PROPN': 29,
#  'ADP|sobre,PROPN': 52,
#  'VERB|tratarán,PRON': 2,
#  'DET|diversos,VERB': 6,
#  'NOUN|temas,DET': 11,
#  'VERB|están,PRON': 10,
#  'NOUN|peligros,DET': 4,
#  'ADJ|genética,NOUN': 6,
#  'NOUN|búsqueda,DET': 19,
#  'ADJ|nuevos,ADP': 21,
#  'NOUN|caminos,ADJ': 1,
#  'NOUN|comercialización,DET': 3,
#  'NOUN|grano,ADP': 25,
#  'PROPN|policía,DET': 28,
#  'PROPN|fiscalía,DET': 18,
#  'PROPN|general,PROPN': 40,
#  'VERB|investigan,PROPN': 1,
#  'NOUN|circunstancias,DET': 13,
#  'VERB|provocaron,PRON': 4,
#  'ADJ|grave,DET': 10,
#  'NOUN|crisis,ADJ': 13,
#  'VERB|puso,PRON': 18,
#  'NOUN|peligro,ADP': 19,
#  'ADJ|bancario-financiero,NOUN': 1,
#  'PROPN|rumanía,ADP': 10,
#  'DET|la,PROPN': 86,
#  'ADJ|última,DET': 68,
#  'NOUN|semana,ADJ': 21,
#  'ADP|tras,PUNCT': 116,
#  'VERB|volver,ADP': 29,
#  'NOUN|jueves,PUNCT': 11,
#  'NOUN|calma,DET': 5,
#  'NOUN|mercados,DET': 31,
#  'ADJ|surgida,None': 1,
#  'ADJ|plena,ADP': 14,
#  'NOUN|campaña,ADJ': 16,
#  'NOUN|elecciones,DET': 113,
#  'ADJ|municipales,NOUN': 18,
#  'ADP|del,ADJ': 627,
#  'ADJ|próximo,ADP': 24,
#  'NOUN|domingo,ADJ': 19,
#  'DET|esta,PUNCT': 26,
#  'NOUN|crisis,DET': 51,
#  'AUX|fue,NOUN': 154,
#  'VERB|estimada,AUX': 1,
#  'PROPN|consejo,DET': 39,
#  'PROPN|supremo,PROPN': 11,
#  'PROPN|defensa,ADP': 33,
#  'PROPN|país,ADP': 7,
#  'ADP|como,PROPN': 1,
#  'NOUN|amenaza,PUNCT': 1,
#  'NOUN|seguridad,DET': 27,
#  'ADJ|nacional,NOUN': 69,
#  'ADP|al,PUNCT': 300,
#  'NOUN|ministro,ADJ': 78,
#  'PROPN|mugur,PUNCT': 2,
#  'PROPN|isarescu,PROPN': 2,
#  'PRON|la,PUNCT': 21,
#  'VERB|calificaba,PRON': 3,
#  'NOUN|ataque,PUNCT': 1,
#  'ADJ|concertado,NOUN': 2,
#  'ADJ|especulativo,CCONJ': 1,
#  'NOUN|efectos,DET': 19,
#  'ADJ|negativos,NOUN': 4,
#  'NOUN|plano,ADP': 2,
#  'ADJ|interno,NOUN': 13,
#  'AUX|fueron,ADJ': 10,
#  'NOUN|pánico,DET': 4,
#  'NOUN|desconfianza,DET': 5,
#  'NUM|cientos,ADP': 5,
#  'NUM|miles,ADP': 19,
#  'NOUN|rumanos,ADP': 2,
#  'NOUN|autoridades,DET': 98,
#  'PROPN|estado,ADP': 149,
#  ...}

# %%
contextDict
# Out:
# {'el,None': 2163,
#  'presidente,DET': 326,
#  'del,NOUN': 3987,
#  'órgano,ADP': 3,
#  'regulador,NOUN': 4,
#  'de,ADJ': 2329,
#  'las,ADP': 2367,
#  'telecomunicaciones,DET': 12,
#  'se,PROPN': 415,
#  'mostró,PRON': 47,
#  'partidario,VERB': 8,
#  'completar,ADP': 7,
#  'esta,VERB': 104,
#  'liberalización,DET': 9,
#  'de,NOUN': 16788,
#  'con,NOUN': 990,
#  'otras,ADP': 81,
#  'medidas,DET': 45,
#  'que,NOUN': 2755,
#  'incentiven,PRON': 1,
#  'la,VERB': 2382,
#  'competencia,DET': 46,
#  'como,NOUN': 326,
#  'puede,SCONJ': 16,
#  'ser,NOUN': 4,
#  'abrir,NOUN': 1,
#  'el,VERB': 2564,
#  'acceso,DET': 21,
#  'a,NOUN': 1900,
#  'la,ADP': 9149,
#  'información,DET': 39,
#  'los,ADP': 4008,
#  'clientes,DET': 15,
#  'telefónica,ADP': 53,
#  'a,PROPN': 256,
#  'otros,ADP': 137,
#  'operadores,DET': 7,
#  '.,NOUN': 5650,
#  'sobre,None': 26,
#  'oferta,DET': 44,
#  'interconexión,ADP': 5,
#  'de,PROPN': 2321,
#  'acaba,PRON': 11,
#  'de,VERB': 1191,
#  'aprobar,ADP': 5,
#  'cmt,DET': 1,
#  ',,PROPN': 7038,
#  'vázquez,PUNCT': 1,
#  'quintana,PROPN': 5,
#  'dijo,PROPN': 53,
#  'que,VERB': 2755,
#  'para,SCONJ': 41,
#  'desarrollarla,ADP': 1,
#  'desarrollar,_': 3,
#  'han,PRON': 278,
#  'escuchado,AUX': 6,
#  'a,VERB': 3118,
#  'actuales,NOUN': 15,
#  'y,ADJ': 1609,
#  'a,CCONJ': 251,
#  'que,PRON': 812,
#  'pronto,PRON': 3,
#  'darán,ADV': 2,
#  'servicios,VERB': 10,
#  'y,NOUN': 3433,
#  'que,CCONJ': 596,
#  'al,SCONJ': 30,
#  'tener,ADP': 54,
#  'aunar,SCONJ': 1,
#  'tantos,VERB': 4,
#  'intereses,DET': 32,
#  'es,NOUN': 514,
#  'imposible,AUX': 14,
#  'dejar,ADJ': 1,
#  'satisfechos,VERB': 2,
#  'a,ADJ': 862,
#  'todos,ADP': 153,
#  '.,PRON': 276,
#  'afirmó,None': 6,
#  'sigue,SCONJ': 4,
#  'criterio,DET': 6,
#  'europeo,NOUN': 30,
#  'trata,SCONJ': 3,
#  'incentivar,ADP': 2,
#  'mercado,DET': 85,
#  'donde,NOUN': 77,
#  'no,PRON': 405,
#  'lo,ADV': 122,
#  'hay,PRON': 44,
#  '.,AUX': 17,
#  'la,None': 1275,
#  'inversión,DET': 34,
#  'en,NOUN': 2968,
#  'investigación,ADP': 28,
#  'básica,NOUN': 9,
#  'es,ADJ': 156,
#  'el,AUX': 405,
#  'camino,DET': 29,
#  'para,NOUN': 1140,
#  'el,ADP': 4513,
#  'crecimiento,DET': 38,
#  'la,CCONJ': 621,
#  'prosperidad,DET': 8,
#  'económica,NOUN': 53,
#  ',,ADJ': 3302,
#  'afirmaron,PUNCT': 2,
#  'hoy,VERB': 451,
#  'empresarios,ADV': 1,
#  ',,NOUN': 8456,
#  'el,PUNCT': 1484,
#  'embajador,DET': 7,
#  'eeuu,ADP': 90,
#  'y,PROPN': 1896,
#  'el,CCONJ': 698,
#  'director,DET': 57,
#  'comunidad,DET': 69,
#  'madrid,ADP': 179,
#  'quienes,PUNCT': 11,
#  'abogaron,PRON': 1,
#  'por,VERB': 742,
#  'elevar,ADP': 5,
#  '",DET': 386,
#  'cultura,PUNCT': 5,
#  'científica,NOUN': 7,
#  '",ADJ': 1115,
#  'de,PUNCT': 747,
#  'ciudadanos,DET': 45,
#  'innovación,DET': 5,
#  '",NOUN': 1921,
#  'empresarios,DET': 19,
#  'durante,None': 43,
#  'presentación,DET': 17,
#  'libro,ADP': 7,
#  'la,PUNCT': 1054,
#  'por,PROPN': 173,
#  'medio,ADP': 70,
#  'investigación,DET': 51,
#  '.,PROPN': 2639,
#  'básica,PROPN': 1,
#  'en,PROPN': 685,
#  '",PROPN': 642,
#  ',,PUNCT': 1950,
#  'editado,PUNCT': 2,
#  'por,ADJ': 959,
#  'secretario,DET': 65,
#  'general,NOUN': 136,
#  'confederación,DET': 9,
#  'empresarial,PROPN': 1,
#  'madrid-ceoe,ADP': 1,
#  '(,PROPN': 894,
#  'ceim,PUNCT': 1,
#  '),PROPN': 772,
#  'alejandro,PUNCT': 7,
#  'couceiro,PROPN': 1,
#  'abogó,PUNCT': 4,
#  'formación,DET': 65,
#  'investigadores,DET': 6,
#  'temas,ADP': 7,
#  'innovación,ADP': 2,
#  'tecnológica,NOUN': 7,
#  '.,ADJ': 2487,
#  'tras,None': 71,
#  'indicar,ADP': 3,
#  'la,SCONJ': 804,
#  'media,NOUN': 11,
#  'en,ADJ': 1428,
#  'unión,DET': 87,
#  'europea,PROPN': 91,
#  'sitúa,PRON': 11,
#  'en,VERB': 2558,
#  '1,8,DET': 2,
#  'por,NUM': 415,
#  'ciento,ADP': 388,
#  'del,NUM': 63,
#  'pib,ADP': 9,
#  'frente,PUNCT': 32,
#  'al,NOUN': 650,
#  '2,8,ADP': 2,
#  'en,NUM': 107,
#  'japón,ADP': 26,
#  'eeuu,CCONJ': 7,
#  'couceiro,PUNCT': 1,
#  'españa,SCONJ': 22,
#  'está,PROPN': 68,
#  'en,AUX': 137,
#  '",ADP': 345,
#  'buen,DET': 47,
#  'camino,ADJ': 10,
#  'y,PUNCT': 1547,
#  'se,CCONJ': 230,
#  'está,PRON': 114,
#  'creando,AUX': 5,
#  'un,VERB': 1128,
#  'entorno,DET': 16,
#  'propicio,NOUN': 2,
#  'para,ADJ': 608,
#  'empresarial,NOUN': 12,
#  'en,None': 758,
#  'este,ADP': 390,
#  'sentido,DET': 64,
#  'se,NOUN': 823,
#  'refirió,PRON': 17,
#  'reciente,DET': 15,
#  'creación,ADJ': 2,
#  'ministerio,ADP': 26,
#  'ciencia,ADP': 5,
#  'tecnología,CCONJ': 6,
#  'primeras,DET': 26,
#  'declaraciones,ADJ': 8,
#  'su,ADP': 1571,
#  'titular,DET': 26,
#  'anna,PUNCT': 4,
#  'birulés,PROPN': 6,
#  'sobre,PUNCT': 86,
#  'impulso,DET': 7,
#  'desarrollo,PUNCT': 1,
#  'e,NOUN': 90,
#  'innovación,CCONJ': 2,
#  'representante,DET': 26,
#  'madrileños,NOUN': 2,
#  'aseguró,ADJ': 9,
#  '",SCONJ': 410,
#  'siglo,DET': 21,
#  'xxi,NOUN': 5,
#  'será,NOUN': 53,
#  'ciencia,DET': 17,
#  'tecnología,DET': 16,
#  'ofreció,CCONJ': 2,
#  'apoyo,DET': 55,
#  'activo,PUNCT': 4,
#  'ceim,DET': 1,
#  'consecución,DET': 9,
#  'retos,DET': 5,
#  'fijados,NOUN': 4,
#  'gobierno,DET': 271,
#  'esta,ADP': 278,
#  'materia,DET': 16,
#  'estadounidense,NOUN': 44,
#  'españa,ADP': 255,
#  'edward,PUNCT': 1,
#  'romero,PROPN': 7,
#  'aseguró,PUNCT': 64,
#  'contribuye,ADJ': 3,
#  'destacó,CCONJ': 8,
#  'colaboración,DET': 17,
#  'entre,NOUN': 272,
#  'estados,CCONJ': 6,
#  'unidos,PROPN': 122,
#  'campo,DET': 40,
#  'materializada,PUNCT': 1,
#  'diversos,ADP': 14,
#  'acuerdos,DET': 20,
#  'libro,DET': 40,
#  'presentado,NOUN': 7,
#  'hoy,ADJ': 32,
#  'recoge,ADV': 3,
#  'forma,ADP': 106,
#  'resumida,NOUN': 1,
#  'un,ADJ': 24,
#  'informe,DET': 42,
#  'comité,ADP': 33,
#  'desarrollo,ADP': 34,
#  'económico,PROPN': 7,
#  'en,PUNCT': 1260,
#  'que,DET': 921,
#  'se,PRON': 884,
#  'destaca,PRON': 4,
#  'importancia,DET': 21,
#  'universitaria,ADJ': 2,
#  'americana,ADJ': 1,
#  'propone,CCONJ': 1,
#  'mejorar,VERB': 4,
#  'enseñanza,DET': 5,
#  'asegurar,ADP': 24,
#  'provisión,DET': 2,
#  'futura,NOUN': 2,
#  'científicos,ADP': 4,
#  'sobresalientes,NOUN': 1,
#  'asimismo,None': 26,
#  'defiende,ADV': 4,
#  'financiación,DET': 20,
#  'pública,NOUN': 61,
#  'pone,CCONJ': 2,
#  'manifiesto,ADP': 8,
#  'las,SCONJ': 226,
#  'empresas,DET': 72,
#  'centran,PRON': 4,
#  'más,VERB': 237,
#  'en,ADV': 440,
#  'i,DET': 2,
#  '+,CCONJ': 3,
#  'd,PROPN': 5,
#  'con,PROPN': 188,
#  'objetivos,ADP': 4,
#  'mercado,ADP': 69,
#  'este,None': 83,
#  'documento,DET': 28,
#  'que,PUNCT': 1839,
#  'ha,PRON': 625,
#  'tomado,AUX': 7,
#  'como,VERB': 268,
#  'referencia,ADP': 21,
#  'la,NOUN': 311,
#  'hace,PUNCT': 22,
#  'hincapié,VERB': 5,
#  'que,ADP': 1332,
#  'los,SCONJ': 367,
#  'retornos,DET': 2,
#  'económicos,NOUN': 28,
#  'inversiones,DET': 27,
#  'son,ADJ': 23,
#  '",AUX': 157,
#  'muy,PUNCT': 62,
#  'elevados,ADV': 2,
#  'conocimiento,DET': 11,
#  'básico,NOUN': 6,
#  'tiende,ADJ': 1,
#  'ser,ADP': 213,
#  'explotado,AUX': 1,
#  'innovaciones,ADP': 1,
#  'producen,PRON': 14,
#  'sustanciales,VERB': 1,
#  'beneficios,ADJ': 5,
#  'durante,NOUN': 74,
#  'un,ADP': 1674,
#  'largo,DET': 12,
#  'periodo,ADJ': 9,
#  '.,PUNCT': 1722,
#  'para,None': 136,
#  'cam,DET': 1,
#  'francisco,PUNCT': 20,
#  'josé,PROPN': 26,
#  'rubia,PROPN': 1,
#  'es,PUNCT': 342,
#  'necesario,AUX': 33,
#  'apoyar,ADJ': 1,
#  'fondo,ADP': 32,
#  'calidad,ADP': 14,
#  'incentivar,CCONJ': 1,
#  'con,VERB': 985,
#  'diferentes,ADP': 20,
#  'científicos,DET': 15,
#  'técnicos,CCONJ': 1,
#  'sector,DET': 55,
#  'productivo,NOUN': 2,
#  'portavoz,DET': 90,
#  'pp,ADP': 109,
#  'rafael,PUNCT': 11,
#  'hernando,PROPN': 1,
#  'dijo,PUNCT': 253,
#  'a,ADV': 347,
#  'efe,ADP': 80,
#  'que,PROPN': 315,
#  'agentes,DET': 32,
#  'sociales,NOUN': 43,
#  'deben,ADJ': 4,
#  'acudir,AUX': 2,
#  'mentalidad,ADP': 1,
#  'abierta,PUNCT': 3,
#  'sin,CCONJ': 45,
#  'planteamientos,ADP': 3,
#  'preconcebidos,PUNCT': 1,
#  'a,PUNCT': 587,
#  'cita,DET': 20,
#  'tarde,DET': 54,
#  'gobierno,ADP': 285,
#  'josé,PUNCT': 79,
#  'maría,PROPN': 74,
#  'aznar,PROPN': 38,
#  'hernando,None': 2,
#  'fundamentó,PROPN': 2,
#  'tales,VERB': 3,
#  'premisas,DET': 4,
#  'se,SCONJ': 463,
#  'trata,PRON': 72,
#  'defender,ADP': 22,
#  'los,VERB': 736,
#  'generales,NOUN': 34,
#  'españoles,DET': 17,
#  'máxime,PUNCT': 2,
#  'teniendo,ADV': 2,
#  'cuenta,ADP': 50,
#  'es,PROPN': 217,
#  'país,DET': 258,
#  'más,PRON': 113,
#  'empleo,ADV': 4,
#  'ha,NOUN': 202,
#  'creado,AUX': 19,
#  'y,VERB': 346,
#  'registra,PRON': 6,
#  'mayor,VERB': 8,
#  'crecimiento,ADJ': 5,
#  'económico,NOUN': 50,
#  'opinión,DET': 58,
#  'un,AUX': 390,
#  'hecho,DET': 54,
#  'gran,PUNCT': 17,
#  'relevancia,ADJ': 3,
#  'reunión,DET': 85,
#  'celebrará,PRON': 16,
#  'aznar,VERB': 9,
#  'dirigente,DET': 32,
#  'patronal,DET': 24,
#  'ceoe,NOUN': 2,
#  'cuevas,PROPN': 5,
#  'con,CCONJ': 148,
#  'de,DET': 251,
#  'ccoo,ADP': 17,
#  'fidalgo,PROPN': 4,
#  'ugt,CCONJ': 5,
#  'cándido,PUNCT': 6,
#  'méndez,PROPN': 8,
#  'añadió,None': 9,
#  'el,SCONJ': 1095,
#  'interés,DET': 22,
#  'aznar,ADP': 26,
#  'entrevistarse,ADP': 3,
#  'entrevistar,_': 4,
#  'se,VERB': 851,
#  'con,PRON': 109,
#  'máximos,DET': 9,
#  'representantes,ADJ': 3,
#  'empresariales,NOUN': 10,
#  'sindicales,CCONJ': 2,
#  'una,AUX': 276,
#  'muestra,DET': 14,
#  'talante,DET': 7,
#  'seguir,ADP': 31,
#  'proceso,DET': 92,
#  'diálogo,ADP': 18,
#  'social,NOUN': 72,
#  '",PUNCT': 495,
#  'eje,PUNCT': 2,
#  'política,DET': 107,
#  'tan,PRON': 15,
#  'buenos,ADV': 5,
#  'resultados,ADJ': 12,
#  'ha,PUNCT': 253,
#  'tenido,AUX': 73,
#  'para,VERB': 292,
#  'empleo,DET': 20,
#  'seguridad,DET': 42,
#  'social,PROPN': 27,
#  'destacó,PROPN': 22,
#  'reforma,DET': 51,
#  'laboral,NOUN': 51,
#  '1997,ADP': 47,
#  'fruto,PUNCT': 3,
#  'alcanzados,NOUN': 1,
#  'con,ADJ': 407,
#  'tuvo,PUNCT': 14,
#  'efectos,VERB': 8,
#  'extraordinarios,PUNCT': 1,
#  'sirvió,CCONJ': 3,
#  'frenar,ADP': 11,
#  'desbocado,PUNCT': 1,
#  'inestabilidad,DET': 7,
#  'que,ADJ': 995,
#  'produjo,PRON': 47,
#  'partir,ADP': 93,
#  '1986,ADP': 8,
#  'además,None': 115,
#  'de,ADV': 1118,
#  'acabar,ADP': 19,
#  'contratos,DET': 16,
#  'basura,PUNCT': 1,
#  'señaló,PROPN': 29,
#  'dicha,SCONJ': 2,
#  'reforma,ADJ': 6,
#  'introdujo,NOUN': 3,
#  'sistema,DET': 88,
#  'ayudas,ADP': 3,
#  'contratación,DET': 11,
#  'indefinida,NOUN': 2,
#  'así,PUNCT': 87,
#  'como,ADV': 109,
#  'remodelación,DET': 3,
#  'contrato,ADP': 8,
#  'estable,NOUN': 8,
#  'tiempo,ADP': 48,
#  'parcial,NOUN': 19,
#  'mejorado,AUX': 5,
#  'las,VERB': 655,
#  'relaciones,DET': 44,
#  'laborales,NOUN': 20,
#  'a,None': 206,
#  'juicio,ADP': 23,
#  'hernando,ADP': 1,
#  'seguir,ADJ': 1,
#  'avanzando,VERB': 1,
#  'fin,ADP': 50,
#  'crear,ADP': 25,
#  'rebajar,PUNCT': 1,
#  'tasa,DET': 30,
#  'temporalidad,ADP': 1,
#  'combatir,CCONJ': 3,
#  'siniestralidad,DET': 10,
#  'trabajo,DET': 72,
#  'komercni,DET': 2,
#  'banka,PROPN': 3,
#  'banco,PUNCT': 2,
#  'comercial,PROPN': 6,
#  'uno,PUNCT': 50,
#  'de,PRON': 611,
#  'cuatro,DET': 50,
#  'bancos,NUM': 2,
#  'más,NOUN': 421,
#  'grandes,ADV': 5,
#  'república,DET': 27,
#  'checa,PROPN': 8,
#  'anunció,PUNCT': 40,
#  'que,ADV': 546,
#  'despedirá,SCONJ': 2,
#  '2.300,ADP': 1,
#  'empleados,NUM': 12,
#  'antes,ADV': 23,
#  'finales,ADP': 31,
#  'año,ADP': 117,
#  'dentro,NOUN': 23,
#  'del,ADV': 215,
#  'proceso,ADP': 14,
#  'saneamiento,ADP': 3,
#  'entidad,DET': 40,
#  'estatal,NOUN': 16,
#  'banco,ADP': 50,
#  'radovan,PUNCT': 1,
#  'vrava,PROPN': 1,
#  'señaló,PUNCT': 64,
#  'motivo,DET': 16,
#  'principal,NOUN': 21,
#  'la,AUX': 314,
#  'reestructuración,DET': 5,
#  'no,CCONJ': 288,
#  'sólo,ADV': 24,
#  'la,ADV': 293,
#  'reducción,DET': 30,
#  'costes,DET': 13,
#  'estado,DET': 84,
#  'dispone,PROPN': 2,
#  'del,VERB': 174,
#  '60,ADP': 23,
#  'de,NUM': 683,
#  'acciones,DET': 34,
#  'komercni,ADP': 1,
#  'checo,PROPN': 3,
#  'quiere,ADJ': 7,
#  'comenzar,VERB': 1,
#  'privatización,ADP': 4,
#  'banco,DET': 60,
#  'ya,NOUN': 80,
#  'año,DET': 260,
#  'terminarlo,CCONJ': 1,
#  'terminar,_': 1,
#  'lo,VERB': 278,
#  'en,PRON': 350,
#  'septiembre,ADP': 49,
#  '2001,ADP': 21,
#  '.,NUM': 190,
#  'otro,None': 17,
#  'objetivos,DET': 16,
#  'evitar,AUX': 9,
#  'repitan,PRON': 3,
#  'errores,DET': 11,
#  'pasado,ADP': 51,
#  'obligaron,PRON': 3,
#  'al,VERB': 866,
#  'comprar,ADP': 10,
#  'créditos,VERB': 1,
#  'dudosos,NOUN': 1,
#  'valor,DET': 39,
#  '60.000,ADP': 1,
#  'millones,NUM': 490,
#  'coronas,ADP': 4,
#  '(,NOUN': 333,
#  'unos,PUNCT': 27,
#  '1.500,PRON': 1,
#  'dólares,ADP': 110,
#  '),NOUN': 369,
#  'esto,None': 21,
#  'permitirá,PRON': 9,
#  'sanear,NOUN': 1,
#  'su,VERB': 643,
#  'portafolio,DET': 2,
#  'es,PRON': 259,
#  'condición,AUX': 2,
#  'continuar,ADP': 12,
#  'privatización,DET': 5,
#  'nueva,DET': 151,
#  'dirección,ADJ': 3,
#  'está,NOUN': 90,
#  'trabajando,AUX': 6,
#  'recuperar,ADP': 16,
#  'prestigio,DET': 3,
#  'institución,DET': 19,
#  'debido,NOUN': 16,
#  'al,ADJ': 279,
#  'escándalo,ADP': 4,
#  'por,NOUN': 790,
#  'violación,DET': 5,
#  'límites,DET': 6,
#  'crédito,ADP': 16,
#  'sus,ADP': 552,
#  'negocios,DET': 9,
#  'austriacas,NOUN': 3,
#  'c.,ADJ': 1,
#  'l.,PROPN': 4,
#  'tradung,PROPN': 1,
#  'otras,CCONJ': 34,
#  ',,PRON': 663,
#  'supusieron,PRON': 2,
#  'pérdidas,VERB': 4,
#  'unos,ADP': 109,
#  '200,PRON': 4,
#  'el,NOUN': 361,
#  'pasado,NOUN': 139,
#  'ese,None': 23,
#  'escándalo,DET': 15,
#  'provocó,NOUN': 6,
#  'amplios,VERB': 1,
#  'cambios,ADJ': 3,
#  'directivos,ADP': 6,
#  'los,DET': 184,
#  'niveles,DET': 6,
#  'desde,PUNCT': 77,
#  'presidente,CCONJ': 7,
#  'jan,NOUN': 1,
#  'kollert,PROPN': 1,
#  'otros,CCONJ': 58,
#  'miembros,DET': 40,
#  'dirección,DET': 65,
#  'hasta,NOUN': 97,
#  'personal,ADP': 9,
#  'medio,NOUN': 11,
#  'tenía,PROPN': 10,
#  'una,VERB': 940,
#  'plantilla,DET': 35,
#  '13.487,ADP': 1,
#  'fines,ADP': 6,
#  '1999,ADP': 115,
#  '470,PUNCT': 1,
#  'fueron,NUM': 8,
#  'despedidos,AUX': 1,
#  'durante,VERB': 67,
#  'primer,DET': 189,
#  'trimestre,ADJ': 16,
#  'presente,ADP': 6,
#  'año,ADJ': 59,
#  '170,PRON': 1,
#  'funcionarios,NUM': 3,
#  'fueron,NOUN': 47,
#  'trasladados,AUX': 7,
#  'una,ADP': 1176,
#  'filial,DET': 21,
#  'otros,DET': 28,
#  'bancos,DET': 14,
#  'checos,NOUN': 1,
#  'se,ADJ': 202,
#  'acompañando,AUX': 1,
#  'caja,DET': 18,
#  'ahorros,ADP': 7,
#  'ya,PUNCT': 249,
#  'comprada,ADV': 1,
#  'erste,DET': 1,
#  'basnk,PROPN': 1,
#  'austria,ADP': 14,
#  'reducido,AUX': 10,
#  'desde,NOUN': 78,
#  '18.700,ADP': 1,
#  '1996,ADP': 32,
#  'actuales,DET': 7,
#  '15.100,ADJ': 1,
#  'y,NUM': 157,
#  'tiene,CCONJ': 17,
#  'planeado,VERB': 1,
#  'reducirlo,ADJ': 1,
#  'reducir,_': 3,
#  'a,PRON': 265,
#  '14.000,ADP': 2,
#  'antes,NUM': 2,
#  'también,None': 103,
#  'el,ADV': 310,
#  'checoslovaco,PROPN': 1,
#  'csob,PUNCT': 1,
#  'adquirido,PUNCT': 1,
#  'belga,NOUN': 3,
#  'kbc,ADJ': 1,
#  'inversiones,ADP': 14,
#  'postal,CCONJ': 1,
#  'ipb,PUNCT': 1,
#  '(,PUNCT': 35,
#  'nomura,ADP': 1,
#  'preparan,PUNCT': 1,
#  'moderada,NOUN': 2,
#  'plantillas,DET': 2,
#  'plantilla,ADP': 4,
#  'últimos,DET': 148,
#  'dos,ADJ': 10,
#  'años,NUM': 530,
#  'estos,ADP': 99,
#  'sido,AUX': 329,
#  'de,AUX': 189,
#  'alrededor,ADP': 3,
#  '8.000,ADP': 4,
#  'pero,PUNCT': 670,
#  'siguen,CCONJ': 3,
#  'teniendo,VERB': 3,
#  'poco,DET': 41,
#  'menos,ADV': 21,
#  '50.000,ADP': 5,
#  'empresa,DET': 162,
#  'canadiense,NOUN': 5,
#  'alcan,ADJ': 1,
#  'aluminium,PROPN': 1,
#  'anunció,PROPN': 34,
#  'jueves,DET': 27,
#  'ha,SCONJ': 60,
#  'llegado,AUX': 36,
#  'acuerdo,DET': 102,
#  'principio,ADP': 38,
#  'fusión,DET': 32,
#  'suiza,DET': 4,
#  'algroup,ADJ': 1,
#  'establece,PRON': 8,
#  'cambio,DET': 51,
#  '17.1,ADP': 1,
#  'acciones,NUM': 2,
#  'alcan,ADP': 4,
#  'cada,ADP': 68,
#  'una,DET': 22,
#  'helvética,NOUN': 1,
#  'también,NOUN': 64,
#  'supone,ADV': 7,
#  'accionistas,DET': 6,
#  'recibirán,NOUN': 1,
#  'pago,DET': 10,
#  'capital,ADP': 20,
#  '90,ADP': 6,
#  'francos,NUM': 4,
#  'suizos,NOUN': 6,
#  '(,ADJ': 157,
#  '53,PUNCT': 1,
#  'dólares,NUM': 60,
#  'un,CCONJ': 145,
#  'dividendo,DET': 2,
#  'especial,NOUN': 35,
#  '135,ADP': 1,
#  '80,PRON': 6,
#  'por,PUNCT': 526,
#  'acción,DET': 40,
#  'algroup,ADP': 6,
#  'estará,ADJ': 1,
#  'condicionado,AUX': 2,
#  'entrega,DET': 9,
#  'intercambio,DET': 11,
#  'del,PROPN': 440,
#  '67,ADP': 2,
#  'circulación,ADP': 11,
#  'de,None': 142,
#  'llevarse,ADP': 1,
#  'llevar,_': 14,
#  'cabo,ADP': 66,
#  'creará,NOUN': 1,
#  'sociedad,DET': 100,
#  'ingresos,ADP': 8,
#  'combinados,NOUN': 2,
#  '12.400,ADP': 1,
#  'mientras,NOUN': 11,
#  'beneficios,DET': 24,
#  'inmediatos,ADJ': 1,
#  'supondrán,ADJ': 1,
#  'menos,ADP': 72,
#  'un,ADV': 124,
#  'ahorro,DET': 5,
#  '150,ADP': 7,
#  'conseguido,AUX': 43,
#  'después,VERB': 30,
#  'alcan,SCONJ': 1,
#  'asegurase,PRON': 1,
#  'bz,ADP': 1,
#  'group,PROPN': 2,
#  'holding,PROPN': 4,
#  'limited,PROPN': 2,
#  'principales,DET': 49,
#  'accionistas,ADJ': 4,
#  'bz,None': 1,
#  'proporcionará,PROPN': 1,
#  '34,DET': 2,
#  'para,PROPN': 291,
#  'través,ADP': 69,
#  'comunicado,DET': 56,
#  'prensa,ADP': 65,
#  'jacques,PUNCT': 3,
#  'bougie,PROPN': 1,
#  'estoy,PUNCT': 16,
#  'seguro,AUX': 9,
#  'esta,SCONJ': 38,
#  'proporcionará,NOUN': 1,
#  'significante,DET': 1,
#  'valor,ADJ': 10,
#  'espero,CCONJ': 4,
#  'fusionar,VERB': 1,
#  'operaciones,DET': 25,
#  'alcan,CCONJ': 1,
#  'industria,ADJ': 3,
#  'líder,NOUN': 2,
#  'nivel,ADP': 19,
#  'global,NOUN': 14,
#  'aluminio,ADP': 5,
#  'embalado,DET': 1,
#  'por,None': 211,
#  'parte,DET': 116,
#  'ejecutivo,NOUN': 16,
#  'sergio,PUNCT': 4,
#  'marchionne,PROPN': 1,
#  'compañía,ADJ': 7,
#  'estará,NOUN': 10,
#  'mejor,ADP': 7,
#  'posición,ADJ': 10,
#  'servir,ADP': 3,
#  'necesidades,DET': 13,
#  'alcan,None': 1,
#  'mayores,DET': 21,
#  'empresas,ADJ': 21,
#  'mundo,ADP': 100,
#  'dedicada,NOUN': 8,
#  'producción,DET': 51,
#  'cuenta,None': 2,
#  'operaciones,ADP': 18,
#  '30,ADP': 32,
#  'países,NUM': 60,
#  'emplea,CCONJ': 1,
#  '30.000,ADP': 2,
#  'personas,NUM': 106,
#  'productos,CCONJ': 4,
#  'derivados,NOUN': 3,
#  'algroup,None': 1,
#  'presente,PUNCT': 2,
#  '18,ADP': 24,
#  '23.000,ADP': 2,
#  'opera,PUNCT': 1,
#  'empaquetado,DET': 1,
#  'con,PUNCT': 482,
#  'fuerte,DET': 35,
#  'presencia,ADJ': 8,
#  'industria,DET': 26,
#  'transporte,ADP': 29,
#  'del,CCONJ': 95,
#  'embalaje,ADP': 1,
#  'productos,ADP': 20,
#  'alimentarios,NOUN': 1,
#  'cosméticos,PUNCT': 1,
#  'farmacéuticos,CCONJ': 3,
#  'consumo,DET': 20,
#  'café,ADP': 61,
#  'alemania,ADP': 28,
#  'aumentó,PROPN': 3,
#  'cerca,VERB': 23,
#  '2,ADP': 4,
#  'según,PUNCT': 312,
#  'estadísticas,DET': 9,
#  'anuales,NOUN': 15,
#  'kraft,NOUN': 1,
#  'foods,PROPN': 5,
#  'bremen,ADP': 3,
#  'sin,None': 101,
#  'embargo,ADP': 155,
#  'lo,ADP': 419,
#  'largo,PRON': 37,
#  'década,DET': 11,
#  'noventa,DET': 3,
#  'registró,PRON': 6,
#  'descenso,DET': 14,
#  'calcula,PRON': 9,
#  'entre,VERB': 90,
#  '1,DET': 6,
#  '2,DET': 17,
#  'actualmente,None': 4,
#  ',,ADV': 1000,
#  'los,PUNCT': 422,
#  'alemanes,DET': 14,
#  'toman,NOUN': 1,
#  'promedio,DET': 8,
#  '6,7,ADP': 2,
#  'kilos,NUM': 22,
#  'persona,ADP': 5,
#  'los,None': 592,
#  'bebedores,ADJ': 1,
#  'europa,ADP': 92,
#  'siguen,PROPN': 4,
#  'siendo,VERB': 35,
#  'los,AUX': 91,
#  'escandinavos,DET': 1,
#  'cerca,ADP': 15,
#  '12,ADP': 24,
#  'más,DET': 148,
#  'reservados,ADV': 2,
#  'portugueses,DET': 1,
#  'apenas,ADP': 15,
#  '4,1,ADV': 1,
#  'cabeza,ADP': 17,
#  'entre,None': 56,
#  '5,DET': 10,
#  '6,DET': 10,
#  'junio,ADP': 73,
#  'encontrarán,PRON': 2,
#  'cerca,PROPN': 1,
#  '200,ADP': 11,
#  'expertos,NUM': 5,
#  'sudamérica,CCONJ': 1,
#  'xii,DET': 2,
#  'congreso,PROPN': 3,
#  'europeo,PROPN': 31,
#  'sobre,PROPN': 52,
#  'tratarán,PRON': 2,
#  'diversos,VERB': 6,
#  'temas,DET': 11,
#  'están,PRON': 61,
#  'peligros,DET': 4,
#  'genética,NOUN': 6,
#  'búsqueda,DET': 19,
#  'nuevos,ADP': 21,
#  'caminos,ADJ': 1,
#  'comercialización,DET': 3,
#  'grano,ADP': 25,
#  'policía,DET': 125,
#  'fiscalía,DET': 33,
#  'general,PROPN': 40,
#  'investigan,PROPN': 1,
#  'circunstancias,DET': 13,
#  'provocaron,PRON': 4,
#  'grave,DET': 10,
#  'crisis,ADJ': 13,
#  'puso,PRON': 18,
#  'peligro,ADP': 19,
#  'bancario-financiero,NOUN': 1,
#  'rumanía,ADP': 10,
#  'la,PROPN': 99,
#  'última,DET': 68,
#  'semana,ADJ': 22,
#  'tras,PUNCT': 116,
#  'volver,ADP': 29,
#  'jueves,PUNCT': 11,
#  'calma,DET': 5,
#  'mercados,DET': 31,
#  'surgida,None': 1,
#  'plena,ADP': 14,
#  'campaña,ADJ': 16,
#  'elecciones,DET': 113,
#  'municipales,NOUN': 18,
#  'del,ADJ': 627,
#  'próximo,ADP': 24,
#  'domingo,ADJ': 19,
#  'esta,PUNCT': 27,
#  'crisis,DET': 51,
#  'fue,NOUN': 155,
#  'estimada,AUX': 1,
#  'consejo,DET': 47,
#  'supremo,PROPN': 11,
#  'defensa,ADP': 56,
#  'país,ADP': 90,
#  'como,PROPN': 120,
#  'amenaza,PUNCT': 1,
#  'nacional,NOUN': 69,
#  'al,PUNCT': 303,
#  'ministro,ADJ': 78,
#  'mugur,PUNCT': 2,
#  'isarescu,PROPN': 2,
#  'calificaba,PRON': 3,
#  'ataque,PUNCT': 1,
#  'concertado,NOUN': 2,
#  'especulativo,CCONJ': 1,
#  'efectos,DET': 19,
#  'negativos,NOUN': 4,
#  'plano,ADP': 2,
#  'interno,NOUN': 13,
#  'fueron,ADJ': 10,
#  'pánico,DET': 4,
#  'desconfianza,DET': 5,
#  'cientos,ADP': 5,
#  'miles,ADP': 20,
#  'rumanos,ADP': 2,
#  'autoridades,DET': 98,
#  'estado,ADP': 179,
#  'mientras,PUNCT': 171,
#  'ámbito,DET': 14,
#  'exterior,NOUN': 32,
#  'fondo,DET': 32,
#  'monetario,PROPN': 8,
#  'internacional,PROPN': 49,
#  'aplazó,PROPN': 1,
#  ',,VERB': 942,
#  'ayer,PUNCT': 7,
#  'miércoles,PUNCT': 18,
#  'prolongación,DET': 3,
#  'acuerdo,ADP': 75,
#  'importancia,ADP': 4,
#  'capital,NOUN': 2,
#  'relanzamiento,DET': 1,
#  'quiebra,DET': 5,
#  'nacional,PROPN': 127,
#  ...}

# %% [markdown]
# ### Entrenamiento del modelo - cálculo de probabilidades
#
# $$P(t_i|w_i, t_{i-1}) = \frac{C(t_i, w_i, t_{i-1})}{C(w_i, t_{i-1})}$$

# %%
# uniqueFeatureDict = {}
# contextDict = {}
posteriorProbDict = {}

for key in uniqueFeatureDict.keys():
  if len(key.split('|'))==2:
    if key is posteriorProbDict.keys():
      posteriorProbDict[key] += uniqueFeatureDict[key]/contextDict[key.split('|')[1]]
    else:
      posteriorProbDict[key] = uniqueFeatureDict[key]/contextDict[key.split('|')[1]]

# %%
# Aquí verificamos que todas las probabilidades 
# por cada contexto 'word,prevtag' suman 1.0
sum_prob_uno = {}

for key in posteriorProbDict.keys():
  if len(key.split('|')) == 2:
    context = key.split('|')[1]
    if  context in sum_prob_uno.keys():
      sum_prob_uno[context] += posteriorProbDict[key]
    else:
      sum_prob_uno[context] = posteriorProbDict[key]

sum(sum_prob_uno.values())/len(sum_prob_uno)
# Out:
# 1.0

# %% [markdown]
# ### Distribución inicial de estados latentes

# %%
# identificamos las categorias gramaticales 'upos' unicas en el corpus
stateSet = {'ADJ',
 'ADP',
 'ADV',
 'AUX',
 'CCONJ',
 'DET',
 'INTJ',
 'NOUN',
 'NUM',
 'PART',
 'PRON',
 'PROPN',
 'PUNCT',
 'SCONJ',
 'SYM',
 'VERB',
 '_'}
# enumeramos las categorias con numeros para asignar a 
# las columnas de la matriz de Viterbi
tagStateDict = {}
for i, state in enumerate(stateSet):
  tagStateDict[state] = i
tagStateDict
# Out:
# {'ADJ': 12,
#  'ADP': 2,
#  'ADV': 4,
#  'AUX': 15,
#  'CCONJ': 6,
#  'DET': 1,
#  'INTJ': 13,
#  'NOUN': 8,
#  'NUM': 5,
#  'PART': 16,
#  'PRON': 14,
#  'PROPN': 3,
#  'PUNCT': 9,
#  'SCONJ': 11,
#  'SYM': 0,
#  'VERB': 10,
#  '_': 7}

# %%
initTagStateProb = {} # \rho_i^{(0)}
from conllu import parse_incr 
wordList = []
data_file = open("UD_Spanish-AnCora/es_ancora-ud-train.conllu", "r", encoding="utf-8")
count = 0 # cuenta la longitud del corpus
for tokenlist in parse_incr(data_file):
  count += 1
  tag = tokenlist[0]['upos']
  if tag in initTagStateProb.keys():
    initTagStateProb[tag] += 1
  else:
    initTagStateProb[tag] = 1

for key in initTagStateProb.keys():
  initTagStateProb[key] /= count

initTagStateProb
# Out:
# {'ADJ': 0.010136315973435861,
#  'ADP': 0.1574274729115694,
#  'ADV': 0.07577770010485844,
#  'AUX': 0.022789234533379936,
#  'CCONJ': 0.036980076896190144,
#  'DET': 0.34799021321216356,
#  'INTJ': 0.0020272631946871723,
#  'NOUN': 0.025026214610276126,
#  'NUM': 0.0068507514854945824,
#  'PART': 0.002446696959105208,
#  'PRON': 0.04173365955959455,
#  'PROPN': 0.10506815798671792,
#  'PUNCT': 0.09143656064313177,
#  'SCONJ': 0.027123383432366307,
#  'SYM': 0.0004893393918210416,
#  'VERB': 0.04557846906675987,
#  '_': 0.0011184900384480952}

# %% [markdown]
# ### Construcción del algoritmo de Viterbi
#
# Dada una secuencia de palabras $\{p_1, p_2, \dots, p_n \}$, y un conjunto de categorias gramaticales dadas por la convención `upos`, se considera la matriz de probabilidades de Viterbi así:
#
# $$
# \begin{array}{c c}
# \begin{array}{c c c c}
# \text{ADJ} \\
# \text{ADV}\\
# \text{PRON} \\
# \vdots \\
# {}
# \end{array}
# &
# \left[
# \begin{array}{c c c c}
# \nu_1(\text{ADJ}) & \nu_2(\text{ADJ}) & \dots  & \nu_n(\text{ADJ})\\
# \nu_1(\text{ADV}) & \nu_2(\text{ADV}) & \dots  & \nu_n(\text{ADV})\\
# \nu_1(\text{PRON}) & \nu_2(\text{PRON}) & \dots  & \nu_n(\text{PRON})\\
# \vdots & \vdots & \dots & \vdots \\ \hdashline
# p_1 & p_2 & \dots & p_n
# \end{array}
# \right]
# \end{array}
# $$
#
# Donde las probabilidades de Viterbi en la primera columna (para una categoria $i$) están dadas por:
#
# $$
# \nu_1(i) = \underbrace{\rho_i^{(0)}}_{\text{probabilidad inicial}} \times P(i \vert p_1, \text{"None"})
# $$
#
# y para las siguientes columnas:
#
# $$
# \nu_{t}(j) = \max_i \{ \overbrace{\nu_{t-1}(i)}^{\text{estado anterior}} \times P(j \vert p_t, i) \}
# $$

# %%
import numpy as np 
import stanza
stanza.download('es')
nlp = stanza.Pipeline('es', processors='tokenize')
import nltk
nltk.download('punkt')
from nltk import word_tokenize
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/master/resources_1.2.0.json: 128kB [00:00, 26.0MB/s]
# 2021-04-12 04:23:17 INFO: Downloading default packages for language: es (Spanish)...
# Downloading http://nlp.stanford.edu/software/stanza/1.2.0/es/default.zip: 100%|██████████| 566M/566M [01:46<00:00, 5.33MB/s]
# 2021-04-12 04:25:13 INFO: Finished downloading models and saved to /root/stanza_resources.
# 2021-04-12 04:25:13 WARNING: Language es package default expects mwt, which has been added
# 2021-04-12 04:25:13 INFO: Loading these models for language: es (Spanish):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | ancora  |
# | mwt       | ancora  |
# =======================
#
# 2021-04-12 04:25:13 INFO: Use device: cpu
# 2021-04-12 04:25:13 INFO: Loading: tokenize
# 2021-04-12 04:25:13 INFO: Loading: mwt
# 2021-04-12 04:25:13 INFO: Done loading processors!

# %%
import nltk
nltk.download('punkt')
from nltk import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
def ViterbiMatrix(secuencia,
                  posteriorProbDict=posteriorProbDict,
                  initTagStateProb=initTagStateProb,
                  tagStateDict=tagStateDict
                  ):
  seq = word_tokenize(secuencia)
  viterbiProb = np.zeros((17, len(seq)))
    # inicialización primera columna
  for key in tagStateDict.keys():
    tag_row = tagStateDict[key]
    word_tag = key+'|'+seq[0].lower()+',None'
    if word_tag in posteriorProbDict.keys():
      viterbiProb[tag_row, 0] = initTagStateProb[key]*posteriorProbDict[word_tag]

  for col in range(1, len(seq)):
    for key in tagStateDict.keys():
      tag_row = tagStateDict[key]
      for prevtag in tagStateDict.keys():
        word_tag = key+'|'+seq[col].lower()+','+prevtag
        if word_tag in posteriorProbDict.keys():
          #Buscamos el máximo
          possible_probs = []
          for key2 in tagStateDict.keys(): 
            tag_row2 = tagStateDict[key2]
            possible_probs.append(
                viterbiProb[tag_row2, col-1]*posteriorProbDict[word_tag])
          viterbiProb[tag_row, col] = max(possible_probs)
        
  return viterbiProb

matrix = ViterbiMatrix('gloria a Dios en el cielo')
matrix
# Out:
# array([[0.00000000e+00, 8.52681929e-05, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 8.52681929e-05, 1.39034526e-03, 0.00000000e+00,
#         2.00209717e-02, 0.00000000e+00],
#        [0.00000000e+00, 2.50262146e-02, 0.00000000e+00, 2.00209717e-02,
#         0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 4.26340964e-05, 2.00209717e-02, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00],
#        [2.50262146e-02, 2.55804579e-04, 5.00524292e-03, 0.00000000e+00,
#         0.00000000e+00, 2.00209717e-02],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 2.00209717e-03],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 1.25131073e-02, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00]])

# %%
def ViterbiTags(secuencia,
                  posteriorProbDict=posteriorProbDict,
                  initTagStateProb=initTagStateProb,
                  tagStateDict=tagStateDict
                  ):
  seq = word_tokenize(secuencia)
  viterbiProb = np.zeros((17, len(seq)))
    # inicialización primera columna
  for key in tagStateDict.keys():
    tag_row = tagStateDict[key]
    word_tag = key+'|'+seq[0].lower()+',None'
    if word_tag in posteriorProbDict.keys():
      viterbiProb[tag_row, 0] = initTagStateProb[key]*posteriorProbDict[word_tag]

  for col in range(1, len(seq)):
    for key in tagStateDict.keys():
      tag_row = tagStateDict[key]
      for prevtag in tagStateDict.keys():
        word_tag = key+'|'+seq[col].lower()+','+prevtag
        if word_tag in posteriorProbDict.keys():
          #Buscamos el máximo
          possible_probs = []
          for key2 in tagStateDict.keys(): 
            tag_row2 = tagStateDict[key2]
            possible_probs.append(
                viterbiProb[tag_row2, col-1]*posteriorProbDict[word_tag])
          viterbiProb[tag_row, col] = max(possible_probs)
        
    # contruccion de secuencia de tags
    res = []
    for i, p in enumerate(seq):
      for tag in tagStateDict.keys():
        if tagStateDict[tag] == np.argmax(viterbiProb[:, i]):
          res.append((p, tag))
      
  return res

ViterbiTags('gloria a Dios en el cielo')
# Out:
# [('gloria', 'NOUN'),
#  ('a', 'ADP'),
#  ('Dios', 'PROPN'),
#  ('en', 'ADP'),
#  ('el', 'DET'),
#  ('cielo', 'NOUN')]

# %%
ViterbiTags('gracias a Dios, entiendo el ejercicio a la perfección')
# Out:
# [('gracias', 'NOUN'),
#  ('a', 'ADP'),
#  ('Dios', 'PROPN'),
#  (',', 'PUNCT'),
#  ('entiendo', 'VERB'),
#  ('el', 'DET'),
#  ('ejercicio', 'NOUN'),
#  ('a', 'ADP'),
#  ('la', 'DET'),
#  ('perfección', 'NOUN')]

# %% [markdown]
# ## ¿ Siguientes Pasos ?
#
# El modelo construido, aunque es la base de un MEMM, no explota todo el potencial del concepto  que estos modelos representan, en nuestro caso sencillo consideramos solo un **feature** para predecir la categoría gramatical: $<w_i, t_{i-1}>$. Es decir, las probabilidades de una cierta etiqueta $t_i$ dada una observación $<w_i, t_{i-1}>$ se calculan contando eventos donde se observe que $<w_i, t_{i-1}>$ sucede simultáneamente con $t_i$.
#
# La generalización de esto (donde puedo considerar multiples observaciones o **features**, y a partir de estos inferir la categoría gramatical) se hace construyendo las llamadas **feature-functions**, donde estas funciones toman valores de 0 o 1, cuando se cumplan las condiciones de la observación o feature en cuestion. En general podemos considerar una **feature-function** como :
#
# $$f_a(t, o) = f_a(\text{tag}, \text{observation}) =
# \begin{cases}
#   1 , & \text{se cumple condición } a \\
#   0, & \text{en caso contrario}
# \end{cases}
# $$
#
# donde la condición $a$ es una relacion entre los valores que tome $\text{tag}$ y $\text{context}$, por ejemplo:
#
# $$f_a(t, o) = f_a(\text{tag}, \text{observation}) =
# \begin{cases}
#   1 , & (t_i, t_{i-1}) = \text{('VERB', 'ADJ')} \\
#   0, & \text{en caso contrario}
# \end{cases}
# $$
#
# Al considerar varias funciones, y por lo tanto varios features observables, consideramos una combinacion lineal de estos por medio de un coeficiente que multiplique a cada función:
#
# $$
# \theta_1 f_1(t, o) + \theta_2 f_2(t, o) + \dots
# $$
#
# donde los coeficientes indicarán cuales features son más relevantes y por lo tanto pesan más para la decisión del resultado del modelo. De esta manera los coeficientes $\theta_j$ se vuelven parámetros del modelo que deben ser optimizados (esto puede realizarse con cualquier técnica de optimizacion como el Gradiente Descendente). Ahora, las probabilidades que pueden obtener usando un softmax sobre estas combinaciones lineales de features:
#
# $$
# P = \prod_i \frac{\exp{\left(\sum_j \theta_j f_j(t_i, o)\right)}}{\sum_{t'}\exp{\left(\sum_j \theta_j f_j(t', o)\right)}}
# $$
#
# Así, lo que buscamos con el algoritmo de optimización es encontrar los parámetros $\theta_j$ que maximizan la probabilidad anterior. En NLTK encontramos la implementación completa de un clasificador de máxima entropia que no esta restringido a relaciones markovianas: https://www.nltk.org/_modules/nltk/classify/maxent.html
#
# Un segmento resumido de la clase en python que implementa este clasificador en NLTK lo encuentras así:
#
# ```
# class MaxentClassifier(ClassifierI):
#
#     def __init__(self, encoding, weights, logarithmic=True):
#         self._encoding = encoding
#         self._weights = weights
#         self._logarithmic = logarithmic
#         assert encoding.length() == len(weights)
#
#     def labels(self):
#         return self._encoding.labels()
#
#     def set_weights(self, new_weights):
#         self._weights = new_weights
#         assert self._encoding.length() == len(new_weights)
#
#
#     def weights(self):
#         return self._weights
#
#     def classify(self, featureset):
#         return self.prob_classify(featureset).max()
#
#     def prob_classify(self, featureset):
#         ### ...
#
#         # Normalize the dictionary to give a probability distribution
#         return DictionaryProbDist(prob_dict, log=self._logarithmic, normalize=True)
#
#     @classmethod
#     def train(
#         cls,
#         train_toks,
#         algorithm=None,
#         trace=3,
#         encoding=None,
#         labels=None,
#         gaussian_prior_sigma=0,
#         **cutoffs
#     ):
#      ### ......
# ```
#
# Donde te das cuenta de la forma que tienen las clases en NLTK que implementan clasificadores generales. Aquí vemos que la clase `MaxentClassifier` es una subclase de una más general `ClassifierI` la cual representa el proceso de clasificación general de categoría única (es decir, que a cada data-point le corresponda solo una categoria), también que esta clase depende de definir un `encoding`
#  y unos pesos `weights` :
#
# ```
# class MaxentClassifier(ClassifierI):
#
#     def __init__(self, encoding, weights, logarithmic=True):
# ```
#
# los pesos corresponden a los parámetros $\theta_i$. Y el encoding es el que corresponde a las funciones $f_a(t, o)$ que dan como resultado valores binarios $1$ o $0$.
#
# La documentación de NLTK te puede dar mas detalles de esta implementación: https://www.nltk.org/api/nltk.classify.html
#
# Finalmente, un ejemplo completo de uso y mejora de un modelo de máxima entropía, lo puedes encontrar en este fork que guarde especialmente para el curso, para que lo tengas de referencia y puedas jugar y aprender con él:
#
# https://github.com/pachocamacho1990/nltk-maxent-pos-tagger
#
# El cual fue desarrollado originalmente por Arne Neumann (https://github.com/arne-cl) basado en los fueatures propuestos por Ratnaparki en 1996 para la tarea de etiquetado por categorias gramaticales.
